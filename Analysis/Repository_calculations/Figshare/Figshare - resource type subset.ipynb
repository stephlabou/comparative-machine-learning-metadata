# %% [markdown]
# # Analysis Template Walkthrough

# %% [markdown]
# # Setup

# %% [markdown]
# ## Select extract
# In order for the template cells to query data from the correct repository, enter the repository name as `repository` and repository object type as `object_type`.

# %%
repository = 'figshare'
object_type = 'articles'

# %%
import pandas as pd
import numpy as np
import re
from pathlib import Path

# %%
#see more rows and columns of output
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %% [markdown]
# ## Helper Functions

# %%
import os, sys
dir2 = os.path.abspath('../')
dir1 = os.path.dirname(dir2)
if not dir1 in sys.path: sys.path.append(dir1)

from utils import analysis
from utils.crosswalk import RepositoryExtract, property_crosswalk
from utils import accessors

# %% [markdown]
# # Summary Statistic Walkthroughs

# %% [markdown]
# Read in the repository .json file

# %%
df = pd.read_json(f'{repository}_{object_type}.json')

# %%
df
# Out:
#              id                                       title_search  \
# 0       9342671  Schools in control? Questions about the develo...
# 1       9490289  Extracting more meaning from CAA results using...
# 2        152586  Large-Scale Mapping and Validation of Escheric...
# 3        622417                  Simplified Support Vector Machine
# 4        152441  Data Preparation Protocols, Additional Results...
# ...         ...                                                ...
# 24208  14107373    Using Machine Learning to Increase NPC Fidelity
# 24209  17114091  Generative Chemical Transformer: Neural Machin...
# 24210  17114094  Anti-hypertensive Peptide Predictor: A Machine...
# 24211  17114097  Anti-hypertensive Peptide Predictor: A Machine...
# 24212  17114100  Anti-hypertensive Peptide Predictor: A Machine...
#
#                                doi_search handle_search  \
# 0                                             2134/1575
# 1                                             2134/1892
# 2            10.1371/journal.pbio.0050008
# 3       10.1371/journal.pcbi.0030020.g001
# 4      10.1371/journal.pcbi.0030020.sd001
# ...                                   ...           ...
# 24208              10.1184/r1/14107373.v2
# 24209       10.1021/acs.jcim.1c01289.s001
# 24210       10.1021/acs.jafc.1c04555.s001
# 24211       10.1021/acs.jafc.1c04555.s002
# 24212       10.1021/acs.jafc.1c04555.s003
#
#                                           url_search published_date_search  \
# 0       https://api.figshare.com/v2/articles/9342671  2006-05-08T15:07:09Z
# 1       https://api.figshare.com/v2/articles/9490289  2006-05-24T15:27:57Z
# 2        https://api.figshare.com/v2/articles/152586  2007-01-09T00:43:06Z
# 3        https://api.figshare.com/v2/articles/622417  2007-02-23T00:40:17Z
# 4        https://api.figshare.com/v2/articles/152441  2007-02-23T00:40:41Z
# ...                                              ...                   ...
# 24208  https://api.figshare.com/v2/articles/14107373  2021-12-02T17:15:02Z
# 24209  https://api.figshare.com/v2/articles/17114091  2021-12-02T18:05:37Z
# 24210  https://api.figshare.com/v2/articles/17114094  2021-12-02T18:06:11Z
# 24211  https://api.figshare.com/v2/articles/17114097  2021-12-02T18:06:12Z
# 24212  https://api.figshare.com/v2/articles/17114100  2021-12-02T18:06:13Z
#
#                                             thumb_search  defined_type_search  \
# 0      https://s3-eu-west-1.amazonaws.com/ppreviews-l...                   14
# 1      https://s3-eu-west-1.amazonaws.com/ppreviews-l...                   14
# 2      https://s3-eu-west-1.amazonaws.com/ppreviews-p...                    3
# 3      https://s3-eu-west-1.amazonaws.com/ppreviews-p...                    1
# 4      https://s3-eu-west-1.amazonaws.com/ppreviews-p...                    3
# ...                                                  ...                  ...
# 24208  https://s3-eu-west-1.amazonaws.com/ppreviews-c...                   18
# 24209  https://ndownloader.figshare.com/files/3164602...                    6
# 24210                                                                       3
# 24211  https://ndownloader.figshare.com/files/3164602...                    6
# 24212  https://ndownloader.figshare.com/files/3164603...                    6
#
#       defined_type_name_search  group_id_search  \
# 0      conference contribution          20438.0
# 1      conference contribution          20438.0
# 2                      dataset            116.0
# 3                       figure            101.0
# 4                      dataset            101.0
# ...                        ...              ...
# 24208                   report           9987.0
# 24209     journal contribution           2409.0
# 24210                  dataset           2505.0
# 24211     journal contribution           2505.0
# 24212     journal contribution           2505.0
#
#                                   url_private_api_search  \
# 0      https://api.figshare.com/v2/account/articles/9...
# 1      https://api.figshare.com/v2/account/articles/9...
# 2      https://api.figshare.com/v2/account/articles/1...
# 3      https://api.figshare.com/v2/account/articles/6...
# 4      https://api.figshare.com/v2/account/articles/1...
# ...                                                  ...
# 24208  https://api.figshare.com/v2/account/articles/1...
# 24209  https://api.figshare.com/v2/account/articles/1...
# 24210  https://api.figshare.com/v2/account/articles/1...
# 24211  https://api.figshare.com/v2/account/articles/1...
# 24212  https://api.figshare.com/v2/account/articles/1...
#
#                                url_public_api_search  \
# 0       https://api.figshare.com/v2/articles/9342671
# 1       https://api.figshare.com/v2/articles/9490289
# 2        https://api.figshare.com/v2/articles/152586
# 3        https://api.figshare.com/v2/articles/622417
# 4        https://api.figshare.com/v2/articles/152441
# ...                                              ...
# 24208  https://api.figshare.com/v2/articles/14107373
# 24209  https://api.figshare.com/v2/articles/17114091
# 24210  https://api.figshare.com/v2/articles/17114094
# 24211  https://api.figshare.com/v2/articles/17114097
# 24212  https://api.figshare.com/v2/articles/17114100
#
#                               url_private_html_search  \
# 0       https://figshare.com/account/articles/9342671
# 1       https://figshare.com/account/articles/9490289
# 2        https://figshare.com/account/articles/152586
# 3        https://figshare.com/account/articles/622417
# 4        https://figshare.com/account/articles/152441
# ...                                               ...
# 24208  https://figshare.com/account/articles/14107373
# 24209  https://figshare.com/account/articles/17114091
# 24210  https://figshare.com/account/articles/17114094
# 24211  https://figshare.com/account/articles/17114097
# 24212  https://figshare.com/account/articles/17114100
#
#                                   url_public_html_search  \
# 0      https://repository.lboro.ac.uk/articles/confer...
# 1      https://repository.lboro.ac.uk/articles/confer...
# 2      https://plos.figshare.com/articles/dataset/Lar...
# 3      https://plos.figshare.com/articles/figure/_Sim...
# 4      https://plos.figshare.com/articles/dataset/Imp...
# ...                                                  ...
# 24208  https://kilthub.cmu.edu/articles/report/Using_...
# 24209  https://acs.figshare.com/articles/journal_cont...
# 24210  https://acs.figshare.com/articles/dataset/Anti...
# 24211  https://acs.figshare.com/articles/journal_cont...
# 24212  https://acs.figshare.com/articles/journal_cont...
#
#                                          timeline_search  \
# 0      {'posted': '2006-05-08T15:07:09', 'publisherPu...
# 1      {'posted': '2006-05-24T15:27:57', 'publisherPu...
# 2      {'posted': '2007-01-09T00:43:06', 'firstOnline...
# 3      {'posted': '2007-02-23T00:40:17', 'firstOnline...
# 4      {'posted': '2007-02-23T00:40:41', 'firstOnline...
# ...                                                  ...
# 24208  {'posted': '2021-12-02T17:15:02', 'firstOnline...
# 24209  {'posted': '2021-12-02T18:05:37', 'publisherPu...
# 24210  {'posted': '2021-12-02T18:06:11', 'publisherPu...
# 24211  {'posted': '2021-12-02T18:06:12', 'publisherPu...
# 24212  {'posted': '2021-12-02T18:06:13', 'publisherPu...
#
#                                    resource_title_search  \
# 0
# 1
# 2      Large-Scale Mapping and Validation of Escheric...
# 3      Improving the <em>Caenorhabditis elegans</em> ...
# 4      Improving the <em>Caenorhabditis elegans</em> ...
# ...                                                  ...
# 24208
# 24209  Generative Chemical Transformer: Neural Machin...
# 24210  Anti-hypertensive Peptide Predictor: A Machine...
# 24211  Anti-hypertensive Peptide Predictor: A Machine...
# 24212  Anti-hypertensive Peptide Predictor: A Machine...
#
#                 resource_doi_search  search_page publish_query  \
# 0                                              1    1950-01-01
# 1                                              1    1950-01-01
# 2      10.1371/journal.pbio.0050008            1    1950-01-01
# 3      10.1371/journal.pcbi.0030020            1    1950-01-01
# 4      10.1371/journal.pcbi.0030020            1    1950-01-01
# ...                             ...          ...           ...
# 24208                                          7    2021-03-21
# 24209      10.1021/acs.jcim.1c01289            7    2021-03-21
# 24210      10.1021/acs.jafc.1c04555            7    2021-03-21
# 24211      10.1021/acs.jafc.1c04555            7    2021-03-21
# 24212      10.1021/acs.jafc.1c04555            7    2021-03-21
#
#                                                  authors  \
# 0      [{'id': 2654377, 'full_name': 'Martin Owen', '...
# 1      [{'id': 7194734, 'full_name': 'S. Valenti', 'i...
# 2      [{'id': 96324, 'full_name': 'Jeremiah J Faith'...
# 3      [{'id': 54319, 'full_name': 'Gunnar Rätsch', '...
# 4      [{'id': 54319, 'full_name': 'Gunnar Rätsch', '...
# ...                                                  ...
# 24208  [{'id': 5441456, 'full_name': 'Dustin Updyke',...
# 24209  [{'id': 10732168, 'full_name': 'Hyunseung Kim'...
# 24210  [{'id': 8441022, 'full_name': 'Gazal Kalyan', ...
# 24211  [{'id': 8441022, 'full_name': 'Gazal Kalyan', ...
# 24212  [{'id': 8441022, 'full_name': 'Gazal Kalyan', ...
#
#                                               categories  \
# 0      [{'id': 1121, 'title': 'Design Practice and Ma...
# 1      [{'id': 2, 'title': 'Uncategorized', 'parent_i...
# 2      [{'id': 48, 'title': 'Biological Sciences', 'p...
# 3      [{'id': 53, 'title': 'Mathematics', 'parent_id...
# 4      [{'id': 53, 'title': 'Mathematics', 'parent_id...
# ...                                                  ...
# 24208  [{'id': 23, 'title': 'Software Engineering', '...
# 24209  [{'id': 4, 'title': 'Biochemistry', 'parent_id...
# 24210  [{'id': 4, 'title': 'Biochemistry', 'parent_id...
# 24211  [{'id': 4, 'title': 'Biochemistry', 'parent_id...
# 24212  [{'id': 4, 'title': 'Biochemistry', 'parent_id...
#
#                                                 citation confidential_reason  \
# 0      Owen, Martin (1993): Schools in control? Quest...
# 1      Valenti, S.; Cucchiarelli, A. (2002): Extracti...
# 2      J Faith, Jeremiah; Hayete, Boris; T Thaden, Jo...
# 3      Rätsch, Gunnar; Sonnenburg, Sören; Srinivasan,...
# 4      Rätsch, Gunnar; Sonnenburg, Sören; Srinivasan,...
# ...                                                  ...                 ...
# 24208  Updyke, Dustin; Podnar, Thomas; Dobson, Geoffr...
# 24209  Kim, Hyunseung; Na, Jonggeol; Lee, Won Bo (202...
# 24210  Kalyan, Gazal; Junghare, Vivek; Khan, Mohammad...
# 24211  Kalyan, Gazal; Junghare, Vivek; Khan, Mohammad...
# 24212  Kalyan, Gazal; Junghare, Vivek; Khan, Mohammad...
#
#                created_date  \
# 0      2006-05-08T15:07:09Z
# 1      2006-05-24T15:27:57Z
# 2      2007-01-09T00:43:06Z
# 3      2007-02-23T00:40:17Z
# 4      2007-02-23T00:40:41Z
# ...                     ...
# 24208  2021-12-02T17:15:02Z
# 24209  2021-12-02T18:05:37Z
# 24210  2021-12-02T18:06:11Z
# 24211  2021-12-02T18:06:12Z
# 24212  2021-12-02T18:06:13Z
#
#                                            custom_fields  \
# 0      [{'name': 'School', 'value': ['Design']}, {'na...
# 1      [{'name': 'School', 'value': ['University Acad...
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 24208  [{'name': 'Publisher Statement', 'value': 'Thi...
# 24209                                                 []
# 24210                                                 []
# 24211                                                 []
# 24212                                                 []
#
#        defined_type_metadata defined_type_name_metadata  \
# 0                         14    conference contribution
# 1                         14    conference contribution
# 2                          3                    dataset
# 3                          1                     figure
# 4                          3                    dataset
# ...                      ...                        ...
# 24208                     18                     report
# 24209                      6       journal contribution
# 24210                      3                    dataset
# 24211                      6       journal contribution
# 24212                      6       journal contribution
#
#                                              description  \
# 0      The paper considers the role of he teaching of...
# 1      This work describes a novel approach to the pr...
# 2      <div><p>Machine learning approaches offer the ...
# 3      <p>Learn a function <i>f</i> such that the dif...
# 4                                    <p>(161 KB PDF)</p>
# ...                                                  ...
# 24208  Experiences that seem real to players in train...
# 24209  Discovering new materials better\nsuited to sp...
# 24210  Angiotensin\nconverting enzyme-I (ACE-I) is a ...
# 24211  Angiotensin\nconverting enzyme-I (ACE-I) is a ...
# 24212  Angiotensin\nconverting enzyme-I (ACE-I) is a ...
#
#                              doi_metadata embargo_date embargo_options  \
# 0                                                 None              []
# 1                                                 None              []
# 2            10.1371/journal.pbio.0050008         None              []
# 3       10.1371/journal.pcbi.0030020.g001         None              []
# 4      10.1371/journal.pcbi.0030020.sd001         None              []
# ...                                   ...          ...             ...
# 24208              10.1184/R1/14107373.v2         None              []
# 24209       10.1021/acs.jcim.1c01289.s001         None              []
# 24210       10.1021/acs.jafc.1c04555.s001         None              []
# 24211       10.1021/acs.jafc.1c04555.s002         None              []
# 24212       10.1021/acs.jafc.1c04555.s003         None              []
#
#       embargo_reason embargo_title embargo_type  \
# 0                                          None
# 1                                          None
# 2                                          None
# 3                                          None
# 4                                          None
# ...              ...           ...          ...
# 24208                                      file
# 24209                                      None
# 24210                                      None
# 24211                                      None
# 24212                                      None
#
#                                             figshare_url  \
# 0      https://repository.lboro.ac.uk/articles/confer...
# 1      https://repository.lboro.ac.uk/articles/confer...
# 2      https://plos.figshare.com/articles/dataset/Lar...
# 3      https://plos.figshare.com/articles/figure/_Sim...
# 4      https://plos.figshare.com/articles/dataset/Imp...
# ...                                                  ...
# 24208  https://kilthub.cmu.edu/articles/report/Using_...
# 24209  https://acs.figshare.com/articles/journal_cont...
# 24210  https://acs.figshare.com/articles/dataset/Anti...
# 24211  https://acs.figshare.com/articles/journal_cont...
# 24212  https://acs.figshare.com/articles/journal_cont...
#
#                                                    files funding funding_list  \
# 0      [{'id': 16951490, 'name': 'owen93.pdf', 'size'...    None           []
# 1      [{'id': 17116004, 'name': 'valenti_s1.pdf', 's...    None           []
# 2      [{'id': 469682, 'name': 'Figure_S1.pdf', 'size...    None           []
# 3      [{'id': 952110, 'name': 'Figure_1.tif', 'size'...    None           []
# 4      [{'id': 468834, 'name': 'Protocol_S1.pdf', 'si...    None           []
# ...                                                  ...     ...          ...
# 24208  [{'id': 31645775, 'name': '2021_005_001_743903...    None           []
# 24209  [{'id': 31646022, 'name': 'ci1c01289_si_001.pd...    None           []
# 24210  [{'id': 31646025, 'name': 'jf1c04555_si_001.xl...    None           []
# 24211  [{'id': 31646028, 'name': 'jf1c04555_si_002.pd...    None           []
# 24212  [{'id': 31646031, 'name': 'jf1c04555_si_003.pd...    None           []
#
#        group_id_metadata handle_metadata  has_linked_file  is_confidential  \
# 0                20438.0       2134/1575                0                0
# 1                20438.0       2134/1892                0                0
# 2                  116.0                                0                0
# 3                  101.0                                0                0
# 4                  101.0                                0                0
# ...                  ...             ...              ...              ...
# 24208             9987.0                                0                0
# 24209             2409.0                                0                0
# 24210             2505.0                                0                0
# 24211             2505.0                                0                0
# 24212             2505.0                                0                0
#
#        is_embargoed  is_metadata_record  is_public  \
# 0                 0                   0          1
# 1                 0                   0          1
# 2                 0                   0          1
# 3                 0                   0          1
# 4                 0                   0          1
# ...             ...                 ...        ...
# 24208             0                   0          1
# 24209             0                   0          1
# 24210             0                   0          1
# 24211             0                   0          1
# 24212             0                   0          1
#
#                                                  license metadata_reason  \
# 0      {'value': 12, 'name': 'CC BY-NC-ND 4.0', 'url'...
# 1      {'value': 12, 'name': 'CC BY-NC-ND 4.0', 'url'...
# 2      {'value': 1, 'name': 'CC BY 4.0', 'url': 'http...
# 3      {'value': 1, 'name': 'CC BY 4.0', 'url': 'http...
# 4      {'value': 1, 'name': 'CC BY 4.0', 'url': 'http...
# ...                                                  ...             ...
# 24208  {'value': 43, 'name': 'In Copyright', 'url': '...
# 24209  {'value': 10, 'name': 'CC BY-NC 4.0', 'url': '...
# 24210  {'value': 10, 'name': 'CC BY-NC 4.0', 'url': '...
# 24211  {'value': 10, 'name': 'CC BY-NC 4.0', 'url': '...
# 24212  {'value': 10, 'name': 'CC BY-NC 4.0', 'url': '...
#
#               modified_date published_date_metadata references  \
# 0      2019-08-19T10:08:03Z    2006-05-08T15:07:09Z         []
# 1      2019-08-19T12:31:31Z    2006-05-24T15:27:57Z         []
# 2      2016-01-18T11:28:43Z    2007-01-09T00:43:06Z         []
# 3      2015-12-02T17:29:15Z    2007-02-23T00:40:17Z         []
# 4      2020-04-27T08:11:31Z    2007-02-23T00:40:41Z         []
# ...                     ...                     ...        ...
# 24208  2021-12-02T17:15:04Z    2021-12-02T17:15:02Z         []
# 24209  2021-12-02T18:05:37Z    2021-12-02T18:05:37Z         []
# 24210  2021-12-02T18:06:11Z    2021-12-02T18:06:11Z         []
# 24211  2021-12-02T18:06:12Z    2021-12-02T18:06:12Z         []
# 24212  2021-12-02T18:06:13Z    2021-12-02T18:06:13Z         []
#
#               resource_doi_metadata  \
# 0                              None
# 1                              None
# 2      10.1371/journal.pbio.0050008
# 3      10.1371/journal.pcbi.0030020
# 4      10.1371/journal.pcbi.0030020
# ...                             ...
# 24208                          None
# 24209      10.1021/acs.jcim.1c01289
# 24210      10.1021/acs.jafc.1c04555
# 24211      10.1021/acs.jafc.1c04555
# 24212      10.1021/acs.jafc.1c04555
#
#                                  resource_title_metadata     size  status  \
# 0                                                   None    49256  public
# 1                                                   None   185571  public
# 2      Large-Scale Mapping and Validation of Escheric...  3358192  public
# 3      Improving the <em>Caenorhabditis elegans</em> ...        0  public
# 4      Improving the <em>Caenorhabditis elegans</em> ...        0  public
# ...                                                  ...      ...     ...
# 24208                                               None   791782  public
# 24209  Generative Chemical Transformer: Neural Machin...  2501061  public
# 24210  Anti-hypertensive Peptide Predictor: A Machine...   153877  public
# 24211  Anti-hypertensive Peptide Predictor: A Machine...   403235  public
# 24212  Anti-hypertensive Peptide Predictor: A Machine...  1206282  public
#
#                                                     tags  \
# 0                                             [untagged]
# 1                                             [untagged]
# 2      [large-scale, validation, transcriptional, com...
# 3                                               [vector]
# 4                        [improving, genome, annotation]
# ...                                                  ...
# 24208  [Machine Learning, modeling, cybersecurity tra...
# 24209  [single condition set, multiple target propert...
# 24210  [key therapeutic target, hypertensive peptide ...
# 24211  [key therapeutic target, hypertensive peptide ...
# 24212  [key therapeutic target, hypertensive peptide ...
#
#                                           thumb_metadata  \
# 0      https://s3-eu-west-1.amazonaws.com/ppreviews-l...
# 1      https://s3-eu-west-1.amazonaws.com/ppreviews-l...
# 2      https://s3-eu-west-1.amazonaws.com/ppreviews-p...
# 3      https://s3-eu-west-1.amazonaws.com/ppreviews-p...
# 4      https://s3-eu-west-1.amazonaws.com/ppreviews-p...
# ...                                                  ...
# 24208  https://s3-eu-west-1.amazonaws.com/ppreviews-c...
# 24209  https://ndownloader.figshare.com/files/3164602...
# 24210
# 24211  https://ndownloader.figshare.com/files/3164602...
# 24212  https://ndownloader.figshare.com/files/3164603...
#
#                                        timeline_metadata  \
# 0      {'posted': '2006-05-08T15:07:09', 'publisherPu...
# 1      {'posted': '2006-05-24T15:27:57', 'publisherPu...
# 2      {'posted': '2007-01-09T00:43:06', 'firstOnline...
# 3      {'posted': '2007-02-23T00:40:17', 'firstOnline...
# 4      {'posted': '2007-02-23T00:40:41', 'firstOnline...
# ...                                                  ...
# 24208  {'posted': '2021-12-02T17:15:02', 'firstOnline...
# 24209  {'posted': '2021-12-02T18:05:37', 'publisherPu...
# 24210  {'posted': '2021-12-02T18:06:11', 'publisherPu...
# 24211  {'posted': '2021-12-02T18:06:12', 'publisherPu...
# 24212  {'posted': '2021-12-02T18:06:13', 'publisherPu...
#
#                                           title_metadata  \
# 0      Schools in control? Questions about the develo...
# 1      Extracting more meaning from CAA results using...
# 2      Large-Scale Mapping and Validation of Escheric...
# 3                      Simplified Support Vector Machine
# 4      Data Preparation Protocols, Additional Results...
# ...                                                  ...
# 24208    Using Machine Learning to Increase NPC Fidelity
# 24209  Generative Chemical Transformer: Neural Machin...
# 24210  Anti-hypertensive Peptide Predictor: A Machine...
# 24211  Anti-hypertensive Peptide Predictor: A Machine...
# 24212  Anti-hypertensive Peptide Predictor: A Machine...
#
#                                         url_metadata  \
# 0       https://api.figshare.com/v2/articles/9342671
# 1       https://api.figshare.com/v2/articles/9490289
# 2        https://api.figshare.com/v2/articles/152586
# 3        https://api.figshare.com/v2/articles/622417
# 4        https://api.figshare.com/v2/articles/152441
# ...                                              ...
# 24208  https://api.figshare.com/v2/articles/14107373
# 24209  https://api.figshare.com/v2/articles/17114091
# 24210  https://api.figshare.com/v2/articles/17114094
# 24211  https://api.figshare.com/v2/articles/17114097
# 24212  https://api.figshare.com/v2/articles/17114100
#
#                                 url_private_api_metadata  \
# 0      https://api.figshare.com/v2/account/articles/9...
# 1      https://api.figshare.com/v2/account/articles/9...
# 2      https://api.figshare.com/v2/account/articles/1...
# 3      https://api.figshare.com/v2/account/articles/6...
# 4      https://api.figshare.com/v2/account/articles/1...
# ...                                                  ...
# 24208  https://api.figshare.com/v2/account/articles/1...
# 24209  https://api.figshare.com/v2/account/articles/1...
# 24210  https://api.figshare.com/v2/account/articles/1...
# 24211  https://api.figshare.com/v2/account/articles/1...
# 24212  https://api.figshare.com/v2/account/articles/1...
#
#                             url_private_html_metadata  \
# 0       https://figshare.com/account/articles/9342671
# 1       https://figshare.com/account/articles/9490289
# 2        https://figshare.com/account/articles/152586
# 3        https://figshare.com/account/articles/622417
# 4        https://figshare.com/account/articles/152441
# ...                                               ...
# 24208  https://figshare.com/account/articles/14107373
# 24209  https://figshare.com/account/articles/17114091
# 24210  https://figshare.com/account/articles/17114094
# 24211  https://figshare.com/account/articles/17114097
# 24212  https://figshare.com/account/articles/17114100
#
#                              url_public_api_metadata  \
# 0       https://api.figshare.com/v2/articles/9342671
# 1       https://api.figshare.com/v2/articles/9490289
# 2        https://api.figshare.com/v2/articles/152586
# 3        https://api.figshare.com/v2/articles/622417
# 4        https://api.figshare.com/v2/articles/152441
# ...                                              ...
# 24208  https://api.figshare.com/v2/articles/14107373
# 24209  https://api.figshare.com/v2/articles/17114091
# 24210  https://api.figshare.com/v2/articles/17114094
# 24211  https://api.figshare.com/v2/articles/17114097
# 24212  https://api.figshare.com/v2/articles/17114100
#
#                                 url_public_html_metadata  version
# 0      https://repository.lboro.ac.uk/articles/confer...        1
# 1      https://repository.lboro.ac.uk/articles/confer...        1
# 2      https://plos.figshare.com/articles/dataset/Lar...        1
# 3      https://plos.figshare.com/articles/figure/_Sim...        1
# 4      https://plos.figshare.com/articles/dataset/Imp...        1
# ...                                                  ...      ...
# 24208  https://kilthub.cmu.edu/articles/report/Using_...        2
# 24209  https://acs.figshare.com/articles/journal_cont...        1
# 24210  https://acs.figshare.com/articles/dataset/Anti...        1
# 24211  https://acs.figshare.com/articles/journal_cont...        1
# 24212  https://acs.figshare.com/articles/journal_cont...        1
#
# [24213 rows x 64 columns]

# %% [markdown]
# Figshare "machine learning" objects include a variety of resource types that are not relevant to the question at hand, such as journal articles, book chapters, and other items.
#
# Full Figshare resource types returned from inital metadata extract, with relevant subset identified in bold:
# * **dataset**
# * journal contribution
# * figure
# * thesis
# * presentation
# * media
# * preprint
# * **software**
# * poster
# * conference contribution
# * online resource
# * chapter
# * book
# * report
# * educational resource
# * **model**
# * workflow

# %% [markdown]
# We want to re-run all summary statistics on this subset of Figshare metadata.

# %%
#subset df based on resource type

# %%
ids = df.FigshareArticlesCrosswalk.unique_identifier
ids
# Out:
# 0         9342671
# 1         9490289
# 2          152586
# 3          622417
# 4          152441
#            ...
# 24208    14107373
# 24209    17114091
# 24210    17114094
# 24211    17114097
# 24212    17114100
# Name: id, Length: 24213, dtype: int64

# %%
resource_types = df.FigshareArticlesCrosswalk.resource_type
resource_types
# Out:
# 0        conference contribution
# 1        conference contribution
# 2                        dataset
# 3                         figure
# 4                        dataset
#                   ...
# 24208                     report
# 24209       journal contribution
# 24210                    dataset
# 24211       journal contribution
# 24212       journal contribution
# Name: defined_type_name_metadata, Length: 24213, dtype: object

# %%
#add ID column to resource type column
resource_ids = pd.concat([ids, resource_types], axis = 1)
resource_ids
# Out:
#              id defined_type_name_metadata
# 0       9342671    conference contribution
# 1       9490289    conference contribution
# 2        152586                    dataset
# 3        622417                     figure
# 4        152441                    dataset
# ...         ...                        ...
# 24208  14107373                     report
# 24209  17114091       journal contribution
# 24210  17114094                    dataset
# 24211  17114097       journal contribution
# 24212  17114100       journal contribution
#
# [24213 rows x 2 columns]

# %%
#keep only ids that are 'dataset', 'software', or 'model'
keep_subset = resource_ids[resource_ids['defined_type_name_metadata'].isin(['dataset', 'software', 'model'])]
keep_ids = keep_subset['id']
keep_ids
# Out:
# 2          152586
# 4          152441
# 9          151745
# 10         151418
# 11         151373
#            ...
# 24204    17113517
# 24205    17113523
# 24206    17113529
# 24207    17113550
# 24210    17114094
# Name: id, Length: 10359, dtype: int64

# %%
#subset full dataset to keep only these ids
subset_df = df[df['id'].isin(keep_ids)]

# %%
subset_df
# Out:
#              id                                       title_search  \
# 2        152586  Large-Scale Mapping and Validation of Escheric...
# 4        152441  Data Preparation Protocols, Additional Results...
# 9        151745  Module-Based Outcome Prediction Using Breast C...
# 10       151418  Activation of Inflammation/NF-κB Signaling in ...
# 11       151373  Intragenomic Matching Reveals a Huge Potential...
# ...         ...                                                ...
# 24204  17113517  Supplementary Table 2: Unsupervised learning o...
# 24205  17113523  Supplementary Table 3: Unsupervised learning o...
# 24206  17113529  Supplementary Table 4: Unsupervised learning o...
# 24207  17113550  Supplementary Table 5: Unsupervised learning o...
# 24210  17114094  Anti-hypertensive Peptide Predictor: A Machine...
#
#                                doi_search handle_search  \
# 2            10.1371/journal.pbio.0050008
# 4      10.1371/journal.pcbi.0030020.sd001
# 9            10.1371/journal.pone.0001047
# 10           10.1371/journal.pgen.0030207
# 11           10.1371/journal.pcbi.0030238
# ...                                   ...           ...
# 24204            10.25402/fon.17113517.v2
# 24205            10.25402/fon.17113523.v2
# 24206            10.25402/fon.17113529.v2
# 24207            10.25402/fon.17113550.v2
# 24210       10.1021/acs.jafc.1c04555.s001
#
#                                           url_search published_date_search  \
# 2        https://api.figshare.com/v2/articles/152586  2007-01-09T00:43:06Z
# 4        https://api.figshare.com/v2/articles/152441  2007-02-23T00:40:41Z
# 9        https://api.figshare.com/v2/articles/151745  2007-10-17T00:29:05Z
# 10       https://api.figshare.com/v2/articles/151418  2007-11-23T00:23:38Z
# 11       https://api.figshare.com/v2/articles/151373  2007-11-30T00:22:53Z
# ...                                              ...                   ...
# 24204  https://api.figshare.com/v2/articles/17113517  2021-12-02T15:58:43Z
# 24205  https://api.figshare.com/v2/articles/17113523  2021-12-02T15:59:13Z
# 24206  https://api.figshare.com/v2/articles/17113529  2021-12-02T15:59:36Z
# 24207  https://api.figshare.com/v2/articles/17113550  2021-12-02T15:59:52Z
# 24210  https://api.figshare.com/v2/articles/17114094  2021-12-02T18:06:11Z
#
#                                             thumb_search  defined_type_search  \
# 2      https://s3-eu-west-1.amazonaws.com/ppreviews-p...                    3
# 4      https://s3-eu-west-1.amazonaws.com/ppreviews-p...                    3
# 9      https://s3-eu-west-1.amazonaws.com/ppreviews-p...                    3
# 10     https://s3-eu-west-1.amazonaws.com/ppreviews-p...                    3
# 11     https://s3-eu-west-1.amazonaws.com/ppreviews-p...                    3
# ...                                                  ...                  ...
# 24204  https://s3-eu-west-1.amazonaws.com/ppreviews-f...                    3
# 24205  https://s3-eu-west-1.amazonaws.com/ppreviews-f...                    3
# 24206  https://s3-eu-west-1.amazonaws.com/ppreviews-f...                    3
# 24207  https://s3-eu-west-1.amazonaws.com/ppreviews-f...                    3
# 24210                                                                       3
#
#       defined_type_name_search  group_id_search  \
# 2                      dataset            116.0
# 4                      dataset            101.0
# 9                      dataset            107.0
# 10                     dataset             98.0
# 11                     dataset            101.0
# ...                        ...              ...
# 24204                  dataset          21381.0
# 24205                  dataset          21381.0
# 24206                  dataset          21381.0
# 24207                  dataset          21381.0
# 24210                  dataset           2505.0
#
#                                   url_private_api_search  \
# 2      https://api.figshare.com/v2/account/articles/1...
# 4      https://api.figshare.com/v2/account/articles/1...
# 9      https://api.figshare.com/v2/account/articles/1...
# 10     https://api.figshare.com/v2/account/articles/1...
# 11     https://api.figshare.com/v2/account/articles/1...
# ...                                                  ...
# 24204  https://api.figshare.com/v2/account/articles/1...
# 24205  https://api.figshare.com/v2/account/articles/1...
# 24206  https://api.figshare.com/v2/account/articles/1...
# 24207  https://api.figshare.com/v2/account/articles/1...
# 24210  https://api.figshare.com/v2/account/articles/1...
#
#                                url_public_api_search  \
# 2        https://api.figshare.com/v2/articles/152586
# 4        https://api.figshare.com/v2/articles/152441
# 9        https://api.figshare.com/v2/articles/151745
# 10       https://api.figshare.com/v2/articles/151418
# 11       https://api.figshare.com/v2/articles/151373
# ...                                              ...
# 24204  https://api.figshare.com/v2/articles/17113517
# 24205  https://api.figshare.com/v2/articles/17113523
# 24206  https://api.figshare.com/v2/articles/17113529
# 24207  https://api.figshare.com/v2/articles/17113550
# 24210  https://api.figshare.com/v2/articles/17114094
#
#                               url_private_html_search  \
# 2        https://figshare.com/account/articles/152586
# 4        https://figshare.com/account/articles/152441
# 9        https://figshare.com/account/articles/151745
# 10       https://figshare.com/account/articles/151418
# 11       https://figshare.com/account/articles/151373
# ...                                               ...
# 24204  https://figshare.com/account/articles/17113517
# 24205  https://figshare.com/account/articles/17113523
# 24206  https://figshare.com/account/articles/17113529
# 24207  https://figshare.com/account/articles/17113550
# 24210  https://figshare.com/account/articles/17114094
#
#                                   url_public_html_search  \
# 2      https://plos.figshare.com/articles/dataset/Lar...
# 4      https://plos.figshare.com/articles/dataset/Imp...
# 9      https://plos.figshare.com/articles/dataset/Mod...
# 10     https://plos.figshare.com/articles/dataset/Act...
# 11     https://plos.figshare.com/articles/dataset/Int...
# ...                                                  ...
# 24204  https://future-science-group.figshare.com/arti...
# 24205  https://future-science-group.figshare.com/arti...
# 24206  https://future-science-group.figshare.com/arti...
# 24207  https://future-science-group.figshare.com/arti...
# 24210  https://acs.figshare.com/articles/dataset/Anti...
#
#                                          timeline_search  \
# 2      {'posted': '2007-01-09T00:43:06', 'firstOnline...
# 4      {'posted': '2007-02-23T00:40:41', 'firstOnline...
# 9      {'posted': '2007-10-17T00:29:05', 'firstOnline...
# 10     {'posted': '2007-11-23T00:23:38', 'firstOnline...
# 11     {'posted': '2007-11-30T00:22:53', 'firstOnline...
# ...                                                  ...
# 24204  {'posted': '2021-12-02T15:58:43', 'firstOnline...
# 24205  {'posted': '2021-12-02T15:59:13', 'firstOnline...
# 24206  {'posted': '2021-12-02T15:59:36', 'firstOnline...
# 24207  {'posted': '2021-12-02T15:59:52', 'firstOnline...
# 24210  {'posted': '2021-12-02T18:06:11', 'publisherPu...
#
#                                    resource_title_search  \
# 2      Large-Scale Mapping and Validation of Escheric...
# 4      Improving the <em>Caenorhabditis elegans</em> ...
# 9      Module-Based Outcome Prediction Using Breast C...
# 10     Activation of Inflammation/NF-κB Signaling in ...
# 11     Intragenomic Matching Reveals a Huge Potential...
# ...                                                  ...
# 24204  Unsupervised learning of cross-modal mappings ...
# 24205  Unsupervised learning of cross-modal mappings ...
# 24206  Unsupervised learning of cross-modal mappings ...
# 24207  Unsupervised learning of cross-modal mappings ...
# 24210  Anti-hypertensive Peptide Predictor: A Machine...
#
#                 resource_doi_search  search_page publish_query  \
# 2      10.1371/journal.pbio.0050008            1    1950-01-01
# 4      10.1371/journal.pcbi.0030020            1    1950-01-01
# 9      10.1371/journal.pone.0001047            1    1950-01-01
# 10     10.1371/journal.pgen.0030207            1    1950-01-01
# 11     10.1371/journal.pcbi.0030238            1    1950-01-01
# ...                             ...          ...           ...
# 24204         10.2217/fon-2021-1059            7    2021-03-21
# 24205         10.2217/fon-2021-1059            7    2021-03-21
# 24206         10.2217/fon-2021-1059            7    2021-03-21
# 24207         10.2217/fon-2021-1059            7    2021-03-21
# 24210      10.1021/acs.jafc.1c04555            7    2021-03-21
#
#                                                  authors  \
# 2      [{'id': 96324, 'full_name': 'Jeremiah J Faith'...
# 4      [{'id': 54319, 'full_name': 'Gunnar Rätsch', '...
# 9      [{'id': 80239, 'full_name': 'Martin H. van Vli...
# 10     [{'id': 272843, 'full_name': 'Rebecca C Fry', ...
# 11     [{'id': 82401, 'full_name': 'Morten Lindow', '...
# ...                                                  ...
# 24204  [{'id': 511385, 'full_name': 'Jianmin Xu', 'is...
# 24205  [{'id': 511385, 'full_name': 'Jianmin Xu', 'is...
# 24206  [{'id': 511385, 'full_name': 'Jianmin Xu', 'is...
# 24207  [{'id': 511385, 'full_name': 'Jianmin Xu', 'is...
# 24210  [{'id': 8441022, 'full_name': 'Gazal Kalyan', ...
#
#                                               categories  \
# 2      [{'id': 48, 'title': 'Biological Sciences', 'p...
# 4      [{'id': 53, 'title': 'Mathematics', 'parent_id...
# 9      [{'id': 13, 'title': 'Genetics', 'parent_id': ...
# 10     [{'id': 13, 'title': 'Genetics', 'parent_id': ...
# 11     [{'id': 12, 'title': 'Cell Biology', 'parent_i...
# ...                                                  ...
# 24204  [{'id': 387, 'title': 'Solid Tumours', 'parent...
# 24205  [{'id': 387, 'title': 'Solid Tumours', 'parent...
# 24206  [{'id': 387, 'title': 'Solid Tumours', 'parent...
# 24207  [{'id': 387, 'title': 'Solid Tumours', 'parent...
# 24210  [{'id': 4, 'title': 'Biochemistry', 'parent_id...
#
#                                                 citation confidential_reason  \
# 2      J Faith, Jeremiah; Hayete, Boris; T Thaden, Jo...
# 4      Rätsch, Gunnar; Sonnenburg, Sören; Srinivasan,...
# 9      H. van Vliet, Martin; N. Klijn, Christiaan; F....
# 10     C Fry, Rebecca; Navasumrit, Panida; Valiathan,...
# 11     Lindow, Morten; Jacobsen, Anders; Nygaard, San...
# ...                                                  ...                 ...
# 24204  Xu, Jianmin; Xu, Binghua; Li, Yipeng; Su, Zhij...
# 24205  Xu, Jianmin; Xu, Binghua; Li, Yipeng; Su, Zhij...
# 24206  Xu, Jianmin; Xu, Binghua; Li, Yipeng; Su, Zhij...
# 24207  Xu, Jianmin; Xu, Binghua; Li, Yipeng; Su, Zhij...
# 24210  Kalyan, Gazal; Junghare, Vivek; Khan, Mohammad...
#
#                created_date custom_fields  defined_type_metadata  \
# 2      2007-01-09T00:43:06Z            []                      3
# 4      2007-02-23T00:40:41Z            []                      3
# 9      2007-10-17T00:29:05Z            []                      3
# 10     2007-11-23T00:23:38Z            []                      3
# 11     2007-11-30T00:22:53Z            []                      3
# ...                     ...           ...                    ...
# 24204  2021-12-02T15:58:43Z            []                      3
# 24205  2021-12-02T15:59:13Z            []                      3
# 24206  2021-12-02T15:59:36Z            []                      3
# 24207  2021-12-02T15:59:52Z            []                      3
# 24210  2021-12-02T18:06:11Z            []                      3
#
#       defined_type_name_metadata  \
# 2                        dataset
# 4                        dataset
# 9                        dataset
# 10                       dataset
# 11                       dataset
# ...                          ...
# 24204                    dataset
# 24205                    dataset
# 24206                    dataset
# 24207                    dataset
# 24210                    dataset
#
#                                              description  \
# 2      <div><p>Machine learning approaches offer the ...
# 4                                    <p>(161 KB PDF)</p>
# 9      <div><h3>Background</h3><p>The availability of...
# 10     <div><p>The long-term health outcome of prenat...
# 11     <div><p>microRNAs (miRNAs) are important post-...
# ...                                                  ...
# 24204  <div>Supplementary Table 2.  Unsupervised lear...
# 24205  <div>Supplementary Table 3.  Unsupervised lear...
# 24206  <div>Supplementary Table 4.  Unsupervised lear...
# 24207  <div>Supplementary Table 5.  Unsupervised lear...
# 24210  Angiotensin\nconverting enzyme-I (ACE-I) is a ...
#
#                              doi_metadata embargo_date embargo_options  \
# 2            10.1371/journal.pbio.0050008         None              []
# 4      10.1371/journal.pcbi.0030020.sd001         None              []
# 9            10.1371/journal.pone.0001047         None              []
# 10           10.1371/journal.pgen.0030207         None              []
# 11           10.1371/journal.pcbi.0030238         None              []
# ...                                   ...          ...             ...
# 24204            10.25402/FON.17113517.v2         None              []
# 24205            10.25402/FON.17113523.v2         None              []
# 24206            10.25402/FON.17113529.v2         None              []
# 24207            10.25402/FON.17113550.v2         None              []
# 24210       10.1021/acs.jafc.1c04555.s001         None              []
#
#       embargo_reason embargo_title embargo_type  \
# 2                                          None
# 4                                          None
# 9                                          None
# 10                                         None
# 11                                         None
# ...              ...           ...          ...
# 24204                                      file
# 24205                                      file
# 24206                                      file
# 24207                                      file
# 24210                                      None
#
#                                             figshare_url  \
# 2      https://plos.figshare.com/articles/dataset/Lar...
# 4      https://plos.figshare.com/articles/dataset/Imp...
# 9      https://plos.figshare.com/articles/dataset/Mod...
# 10     https://plos.figshare.com/articles/dataset/Act...
# 11     https://plos.figshare.com/articles/dataset/Int...
# ...                                                  ...
# 24204  https://future-science-group.figshare.com/arti...
# 24205  https://future-science-group.figshare.com/arti...
# 24206  https://future-science-group.figshare.com/arti...
# 24207  https://future-science-group.figshare.com/arti...
# 24210  https://acs.figshare.com/articles/dataset/Anti...
#
#                                                    files funding funding_list  \
# 2      [{'id': 469682, 'name': 'Figure_S1.pdf', 'size...    None           []
# 4      [{'id': 468834, 'name': 'Protocol_S1.pdf', 'si...    None           []
# 9      [{'id': 465350, 'name': 'Text_S1.doc', 'size':...    None           []
# 10     [{'id': 463877, 'name': 'Figure_S1.pdf', 'size...    None           []
# 11     [{'id': 6649146, 'name': 'Dataset S1.TDS', 'si...    None           []
# ...                                                  ...     ...          ...
# 24204  [{'id': 31645340, 'name': 'Supplementary Table...    None           []
# 24205  [{'id': 31645343, 'name': 'Supplementary Table...    None           []
# 24206  [{'id': 31645349, 'name': 'Supplementary Table...    None           []
# 24207  [{'id': 31645355, 'name': 'Supplementary Table...    None           []
# 24210  [{'id': 31646025, 'name': 'jf1c04555_si_001.xl...    None           []
#
#        group_id_metadata handle_metadata  has_linked_file  is_confidential  \
# 2                  116.0                                0                0
# 4                  101.0                                0                0
# 9                  107.0                                0                0
# 10                  98.0                                0                0
# 11                 101.0                                0                0
# ...                  ...             ...              ...              ...
# 24204            21381.0                                0                0
# 24205            21381.0                                0                0
# 24206            21381.0                                0                0
# 24207            21381.0                                0                0
# 24210             2505.0                                0                0
#
#        is_embargoed  is_metadata_record  is_public  \
# 2                 0                   0          1
# 4                 0                   0          1
# 9                 0                   0          1
# 10                0                   0          1
# 11                0                   0          1
# ...             ...                 ...        ...
# 24204             0                   0          1
# 24205             0                   0          1
# 24206             0                   0          1
# 24207             0                   0          1
# 24210             0                   0          1
#
#                                                  license metadata_reason  \
# 2      {'value': 1, 'name': 'CC BY 4.0', 'url': 'http...
# 4      {'value': 1, 'name': 'CC BY 4.0', 'url': 'http...
# 9      {'value': 1, 'name': 'CC BY 4.0', 'url': 'http...
# 10     {'value': 1, 'name': 'CC BY 4.0', 'url': 'http...
# 11     {'value': 1, 'name': 'CC BY 4.0', 'url': 'http...
# ...                                                  ...             ...
# 24204  {'value': 12, 'name': 'CC BY-NC-ND 4.0', 'url'...
# 24205  {'value': 12, 'name': 'CC BY-NC-ND 4.0', 'url'...
# 24206  {'value': 12, 'name': 'CC BY-NC-ND 4.0', 'url'...
# 24207  {'value': 12, 'name': 'CC BY-NC-ND 4.0', 'url'...
# 24210  {'value': 10, 'name': 'CC BY-NC 4.0', 'url': '...
#
#               modified_date published_date_metadata references  \
# 2      2016-01-18T11:28:43Z    2007-01-09T00:43:06Z         []
# 4      2020-04-27T08:11:31Z    2007-02-23T00:40:41Z         []
# 9      2016-01-18T12:04:10Z    2007-10-17T00:29:05Z         []
# 10     2016-01-18T12:04:14Z    2007-11-23T00:23:38Z         []
# 11     2016-10-28T06:55:11Z    2007-11-30T00:22:53Z         []
# ...                     ...                     ...        ...
# 24204  2021-12-02T15:58:46Z    2021-12-02T15:58:43Z         []
# 24205  2021-12-02T15:59:15Z    2021-12-02T15:59:13Z         []
# 24206  2021-12-02T15:59:38Z    2021-12-02T15:59:36Z         []
# 24207  2021-12-02T15:59:54Z    2021-12-02T15:59:52Z         []
# 24210  2021-12-02T18:06:11Z    2021-12-02T18:06:11Z         []
#
#               resource_doi_metadata  \
# 2      10.1371/journal.pbio.0050008
# 4      10.1371/journal.pcbi.0030020
# 9      10.1371/journal.pone.0001047
# 10     10.1371/journal.pgen.0030207
# 11     10.1371/journal.pcbi.0030238
# ...                             ...
# 24204         10.2217/fon-2021-1059
# 24205         10.2217/fon-2021-1059
# 24206         10.2217/fon-2021-1059
# 24207         10.2217/fon-2021-1059
# 24210      10.1021/acs.jafc.1c04555
#
#                                  resource_title_metadata      size  status  \
# 2      Large-Scale Mapping and Validation of Escheric...   3358192  public
# 4      Improving the <em>Caenorhabditis elegans</em> ...         0  public
# 9      Module-Based Outcome Prediction Using Breast C...  12532568  public
# 10     Activation of Inflammation/NF-κB Signaling in ...  12846051  public
# 11     Intragenomic Matching Reveals a Huge Potential...   3756384  public
# ...                                                  ...       ...     ...
# 24204  Unsupervised learning of cross-modal mappings ...     77444  public
# 24205  Unsupervised learning of cross-modal mappings ...    185790  public
# 24206  Unsupervised learning of cross-modal mappings ...    137646  public
# 24207  Unsupervised learning of cross-modal mappings ...    109962  public
# 24210  Anti-hypertensive Peptide Predictor: A Machine...    153877  public
#
#                                                     tags  \
# 2      [large-scale, validation, transcriptional, com...
# 4                        [improving, genome, annotation]
# 9                      [module-based, cancer, compendia]
# 10     [activation, signaling, infants, arsenic-expos...
# 11     [support vector machine classification, target...
# ...                                                  ...
# 24204  [machine learning, gastric cancer, disease mod...
# 24205  [machine learning, gastric cancer, disease mod...
# 24206  [machine learning, gastric cancer, disease mod...
# 24207  [machine learning, gastric cancer, disease mod...
# 24210  [key therapeutic target, hypertensive peptide ...
#
#                                           thumb_metadata  \
# 2      https://s3-eu-west-1.amazonaws.com/ppreviews-p...
# 4      https://s3-eu-west-1.amazonaws.com/ppreviews-p...
# 9      https://s3-eu-west-1.amazonaws.com/ppreviews-p...
# 10     https://s3-eu-west-1.amazonaws.com/ppreviews-p...
# 11     https://s3-eu-west-1.amazonaws.com/ppreviews-p...
# ...                                                  ...
# 24204  https://s3-eu-west-1.amazonaws.com/ppreviews-f...
# 24205  https://s3-eu-west-1.amazonaws.com/ppreviews-f...
# 24206  https://s3-eu-west-1.amazonaws.com/ppreviews-f...
# 24207  https://s3-eu-west-1.amazonaws.com/ppreviews-f...
# 24210
#
#                                        timeline_metadata  \
# 2      {'posted': '2007-01-09T00:43:06', 'firstOnline...
# 4      {'posted': '2007-02-23T00:40:41', 'firstOnline...
# 9      {'posted': '2007-10-17T00:29:05', 'firstOnline...
# 10     {'posted': '2007-11-23T00:23:38', 'firstOnline...
# 11     {'posted': '2007-11-30T00:22:53', 'firstOnline...
# ...                                                  ...
# 24204  {'posted': '2021-12-02T15:58:43', 'firstOnline...
# 24205  {'posted': '2021-12-02T15:59:13', 'firstOnline...
# 24206  {'posted': '2021-12-02T15:59:36', 'firstOnline...
# 24207  {'posted': '2021-12-02T15:59:52', 'firstOnline...
# 24210  {'posted': '2021-12-02T18:06:11', 'publisherPu...
#
#                                           title_metadata  \
# 2      Large-Scale Mapping and Validation of Escheric...
# 4      Data Preparation Protocols, Additional Results...
# 9      Module-Based Outcome Prediction Using Breast C...
# 10     Activation of Inflammation/NF-κB Signaling in ...
# 11     Intragenomic Matching Reveals a Huge Potential...
# ...                                                  ...
# 24204  Supplementary Table 2: Unsupervised learning o...
# 24205  Supplementary Table 3: Unsupervised learning o...
# 24206  Supplementary Table 4: Unsupervised learning o...
# 24207  Supplementary Table 5: Unsupervised learning o...
# 24210  Anti-hypertensive Peptide Predictor: A Machine...
#
#                                         url_metadata  \
# 2        https://api.figshare.com/v2/articles/152586
# 4        https://api.figshare.com/v2/articles/152441
# 9        https://api.figshare.com/v2/articles/151745
# 10       https://api.figshare.com/v2/articles/151418
# 11       https://api.figshare.com/v2/articles/151373
# ...                                              ...
# 24204  https://api.figshare.com/v2/articles/17113517
# 24205  https://api.figshare.com/v2/articles/17113523
# 24206  https://api.figshare.com/v2/articles/17113529
# 24207  https://api.figshare.com/v2/articles/17113550
# 24210  https://api.figshare.com/v2/articles/17114094
#
#                                 url_private_api_metadata  \
# 2      https://api.figshare.com/v2/account/articles/1...
# 4      https://api.figshare.com/v2/account/articles/1...
# 9      https://api.figshare.com/v2/account/articles/1...
# 10     https://api.figshare.com/v2/account/articles/1...
# 11     https://api.figshare.com/v2/account/articles/1...
# ...                                                  ...
# 24204  https://api.figshare.com/v2/account/articles/1...
# 24205  https://api.figshare.com/v2/account/articles/1...
# 24206  https://api.figshare.com/v2/account/articles/1...
# 24207  https://api.figshare.com/v2/account/articles/1...
# 24210  https://api.figshare.com/v2/account/articles/1...
#
#                             url_private_html_metadata  \
# 2        https://figshare.com/account/articles/152586
# 4        https://figshare.com/account/articles/152441
# 9        https://figshare.com/account/articles/151745
# 10       https://figshare.com/account/articles/151418
# 11       https://figshare.com/account/articles/151373
# ...                                               ...
# 24204  https://figshare.com/account/articles/17113517
# 24205  https://figshare.com/account/articles/17113523
# 24206  https://figshare.com/account/articles/17113529
# 24207  https://figshare.com/account/articles/17113550
# 24210  https://figshare.com/account/articles/17114094
#
#                              url_public_api_metadata  \
# 2        https://api.figshare.com/v2/articles/152586
# 4        https://api.figshare.com/v2/articles/152441
# 9        https://api.figshare.com/v2/articles/151745
# 10       https://api.figshare.com/v2/articles/151418
# 11       https://api.figshare.com/v2/articles/151373
# ...                                              ...
# 24204  https://api.figshare.com/v2/articles/17113517
# 24205  https://api.figshare.com/v2/articles/17113523
# 24206  https://api.figshare.com/v2/articles/17113529
# 24207  https://api.figshare.com/v2/articles/17113550
# 24210  https://api.figshare.com/v2/articles/17114094
#
#                                 url_public_html_metadata  version
# 2      https://plos.figshare.com/articles/dataset/Lar...        1
# 4      https://plos.figshare.com/articles/dataset/Imp...        1
# 9      https://plos.figshare.com/articles/dataset/Mod...        1
# 10     https://plos.figshare.com/articles/dataset/Act...        1
# 11     https://plos.figshare.com/articles/dataset/Int...        1
# ...                                                  ...      ...
# 24204  https://future-science-group.figshare.com/arti...        2
# 24205  https://future-science-group.figshare.com/arti...        2
# 24206  https://future-science-group.figshare.com/arti...        2
# 24207  https://future-science-group.figshare.com/arti...        2
# 24210  https://acs.figshare.com/articles/dataset/Anti...        1
#
# [10359 rows x 64 columns]

# %%
#rename subset_df back to df, so remainder of code identical to full extract
del df
df = subset_df

# %%
df
# Out:
#              id                                       title_search  \
# 2        152586  Large-Scale Mapping and Validation of Escheric...
# 4        152441  Data Preparation Protocols, Additional Results...
# 9        151745  Module-Based Outcome Prediction Using Breast C...
# 10       151418  Activation of Inflammation/NF-κB Signaling in ...
# 11       151373  Intragenomic Matching Reveals a Huge Potential...
# ...         ...                                                ...
# 24204  17113517  Supplementary Table 2: Unsupervised learning o...
# 24205  17113523  Supplementary Table 3: Unsupervised learning o...
# 24206  17113529  Supplementary Table 4: Unsupervised learning o...
# 24207  17113550  Supplementary Table 5: Unsupervised learning o...
# 24210  17114094  Anti-hypertensive Peptide Predictor: A Machine...
#
#                                doi_search handle_search  \
# 2            10.1371/journal.pbio.0050008
# 4      10.1371/journal.pcbi.0030020.sd001
# 9            10.1371/journal.pone.0001047
# 10           10.1371/journal.pgen.0030207
# 11           10.1371/journal.pcbi.0030238
# ...                                   ...           ...
# 24204            10.25402/fon.17113517.v2
# 24205            10.25402/fon.17113523.v2
# 24206            10.25402/fon.17113529.v2
# 24207            10.25402/fon.17113550.v2
# 24210       10.1021/acs.jafc.1c04555.s001
#
#                                           url_search published_date_search  \
# 2        https://api.figshare.com/v2/articles/152586  2007-01-09T00:43:06Z
# 4        https://api.figshare.com/v2/articles/152441  2007-02-23T00:40:41Z
# 9        https://api.figshare.com/v2/articles/151745  2007-10-17T00:29:05Z
# 10       https://api.figshare.com/v2/articles/151418  2007-11-23T00:23:38Z
# 11       https://api.figshare.com/v2/articles/151373  2007-11-30T00:22:53Z
# ...                                              ...                   ...
# 24204  https://api.figshare.com/v2/articles/17113517  2021-12-02T15:58:43Z
# 24205  https://api.figshare.com/v2/articles/17113523  2021-12-02T15:59:13Z
# 24206  https://api.figshare.com/v2/articles/17113529  2021-12-02T15:59:36Z
# 24207  https://api.figshare.com/v2/articles/17113550  2021-12-02T15:59:52Z
# 24210  https://api.figshare.com/v2/articles/17114094  2021-12-02T18:06:11Z
#
#                                             thumb_search  defined_type_search  \
# 2      https://s3-eu-west-1.amazonaws.com/ppreviews-p...                    3
# 4      https://s3-eu-west-1.amazonaws.com/ppreviews-p...                    3
# 9      https://s3-eu-west-1.amazonaws.com/ppreviews-p...                    3
# 10     https://s3-eu-west-1.amazonaws.com/ppreviews-p...                    3
# 11     https://s3-eu-west-1.amazonaws.com/ppreviews-p...                    3
# ...                                                  ...                  ...
# 24204  https://s3-eu-west-1.amazonaws.com/ppreviews-f...                    3
# 24205  https://s3-eu-west-1.amazonaws.com/ppreviews-f...                    3
# 24206  https://s3-eu-west-1.amazonaws.com/ppreviews-f...                    3
# 24207  https://s3-eu-west-1.amazonaws.com/ppreviews-f...                    3
# 24210                                                                       3
#
#       defined_type_name_search  group_id_search  \
# 2                      dataset            116.0
# 4                      dataset            101.0
# 9                      dataset            107.0
# 10                     dataset             98.0
# 11                     dataset            101.0
# ...                        ...              ...
# 24204                  dataset          21381.0
# 24205                  dataset          21381.0
# 24206                  dataset          21381.0
# 24207                  dataset          21381.0
# 24210                  dataset           2505.0
#
#                                   url_private_api_search  \
# 2      https://api.figshare.com/v2/account/articles/1...
# 4      https://api.figshare.com/v2/account/articles/1...
# 9      https://api.figshare.com/v2/account/articles/1...
# 10     https://api.figshare.com/v2/account/articles/1...
# 11     https://api.figshare.com/v2/account/articles/1...
# ...                                                  ...
# 24204  https://api.figshare.com/v2/account/articles/1...
# 24205  https://api.figshare.com/v2/account/articles/1...
# 24206  https://api.figshare.com/v2/account/articles/1...
# 24207  https://api.figshare.com/v2/account/articles/1...
# 24210  https://api.figshare.com/v2/account/articles/1...
#
#                                url_public_api_search  \
# 2        https://api.figshare.com/v2/articles/152586
# 4        https://api.figshare.com/v2/articles/152441
# 9        https://api.figshare.com/v2/articles/151745
# 10       https://api.figshare.com/v2/articles/151418
# 11       https://api.figshare.com/v2/articles/151373
# ...                                              ...
# 24204  https://api.figshare.com/v2/articles/17113517
# 24205  https://api.figshare.com/v2/articles/17113523
# 24206  https://api.figshare.com/v2/articles/17113529
# 24207  https://api.figshare.com/v2/articles/17113550
# 24210  https://api.figshare.com/v2/articles/17114094
#
#                               url_private_html_search  \
# 2        https://figshare.com/account/articles/152586
# 4        https://figshare.com/account/articles/152441
# 9        https://figshare.com/account/articles/151745
# 10       https://figshare.com/account/articles/151418
# 11       https://figshare.com/account/articles/151373
# ...                                               ...
# 24204  https://figshare.com/account/articles/17113517
# 24205  https://figshare.com/account/articles/17113523
# 24206  https://figshare.com/account/articles/17113529
# 24207  https://figshare.com/account/articles/17113550
# 24210  https://figshare.com/account/articles/17114094
#
#                                   url_public_html_search  \
# 2      https://plos.figshare.com/articles/dataset/Lar...
# 4      https://plos.figshare.com/articles/dataset/Imp...
# 9      https://plos.figshare.com/articles/dataset/Mod...
# 10     https://plos.figshare.com/articles/dataset/Act...
# 11     https://plos.figshare.com/articles/dataset/Int...
# ...                                                  ...
# 24204  https://future-science-group.figshare.com/arti...
# 24205  https://future-science-group.figshare.com/arti...
# 24206  https://future-science-group.figshare.com/arti...
# 24207  https://future-science-group.figshare.com/arti...
# 24210  https://acs.figshare.com/articles/dataset/Anti...
#
#                                          timeline_search  \
# 2      {'posted': '2007-01-09T00:43:06', 'firstOnline...
# 4      {'posted': '2007-02-23T00:40:41', 'firstOnline...
# 9      {'posted': '2007-10-17T00:29:05', 'firstOnline...
# 10     {'posted': '2007-11-23T00:23:38', 'firstOnline...
# 11     {'posted': '2007-11-30T00:22:53', 'firstOnline...
# ...                                                  ...
# 24204  {'posted': '2021-12-02T15:58:43', 'firstOnline...
# 24205  {'posted': '2021-12-02T15:59:13', 'firstOnline...
# 24206  {'posted': '2021-12-02T15:59:36', 'firstOnline...
# 24207  {'posted': '2021-12-02T15:59:52', 'firstOnline...
# 24210  {'posted': '2021-12-02T18:06:11', 'publisherPu...
#
#                                    resource_title_search  \
# 2      Large-Scale Mapping and Validation of Escheric...
# 4      Improving the <em>Caenorhabditis elegans</em> ...
# 9      Module-Based Outcome Prediction Using Breast C...
# 10     Activation of Inflammation/NF-κB Signaling in ...
# 11     Intragenomic Matching Reveals a Huge Potential...
# ...                                                  ...
# 24204  Unsupervised learning of cross-modal mappings ...
# 24205  Unsupervised learning of cross-modal mappings ...
# 24206  Unsupervised learning of cross-modal mappings ...
# 24207  Unsupervised learning of cross-modal mappings ...
# 24210  Anti-hypertensive Peptide Predictor: A Machine...
#
#                 resource_doi_search  search_page publish_query  \
# 2      10.1371/journal.pbio.0050008            1    1950-01-01
# 4      10.1371/journal.pcbi.0030020            1    1950-01-01
# 9      10.1371/journal.pone.0001047            1    1950-01-01
# 10     10.1371/journal.pgen.0030207            1    1950-01-01
# 11     10.1371/journal.pcbi.0030238            1    1950-01-01
# ...                             ...          ...           ...
# 24204         10.2217/fon-2021-1059            7    2021-03-21
# 24205         10.2217/fon-2021-1059            7    2021-03-21
# 24206         10.2217/fon-2021-1059            7    2021-03-21
# 24207         10.2217/fon-2021-1059            7    2021-03-21
# 24210      10.1021/acs.jafc.1c04555            7    2021-03-21
#
#                                                  authors  \
# 2      [{'id': 96324, 'full_name': 'Jeremiah J Faith'...
# 4      [{'id': 54319, 'full_name': 'Gunnar Rätsch', '...
# 9      [{'id': 80239, 'full_name': 'Martin H. van Vli...
# 10     [{'id': 272843, 'full_name': 'Rebecca C Fry', ...
# 11     [{'id': 82401, 'full_name': 'Morten Lindow', '...
# ...                                                  ...
# 24204  [{'id': 511385, 'full_name': 'Jianmin Xu', 'is...
# 24205  [{'id': 511385, 'full_name': 'Jianmin Xu', 'is...
# 24206  [{'id': 511385, 'full_name': 'Jianmin Xu', 'is...
# 24207  [{'id': 511385, 'full_name': 'Jianmin Xu', 'is...
# 24210  [{'id': 8441022, 'full_name': 'Gazal Kalyan', ...
#
#                                               categories  \
# 2      [{'id': 48, 'title': 'Biological Sciences', 'p...
# 4      [{'id': 53, 'title': 'Mathematics', 'parent_id...
# 9      [{'id': 13, 'title': 'Genetics', 'parent_id': ...
# 10     [{'id': 13, 'title': 'Genetics', 'parent_id': ...
# 11     [{'id': 12, 'title': 'Cell Biology', 'parent_i...
# ...                                                  ...
# 24204  [{'id': 387, 'title': 'Solid Tumours', 'parent...
# 24205  [{'id': 387, 'title': 'Solid Tumours', 'parent...
# 24206  [{'id': 387, 'title': 'Solid Tumours', 'parent...
# 24207  [{'id': 387, 'title': 'Solid Tumours', 'parent...
# 24210  [{'id': 4, 'title': 'Biochemistry', 'parent_id...
#
#                                                 citation confidential_reason  \
# 2      J Faith, Jeremiah; Hayete, Boris; T Thaden, Jo...
# 4      Rätsch, Gunnar; Sonnenburg, Sören; Srinivasan,...
# 9      H. van Vliet, Martin; N. Klijn, Christiaan; F....
# 10     C Fry, Rebecca; Navasumrit, Panida; Valiathan,...
# 11     Lindow, Morten; Jacobsen, Anders; Nygaard, San...
# ...                                                  ...                 ...
# 24204  Xu, Jianmin; Xu, Binghua; Li, Yipeng; Su, Zhij...
# 24205  Xu, Jianmin; Xu, Binghua; Li, Yipeng; Su, Zhij...
# 24206  Xu, Jianmin; Xu, Binghua; Li, Yipeng; Su, Zhij...
# 24207  Xu, Jianmin; Xu, Binghua; Li, Yipeng; Su, Zhij...
# 24210  Kalyan, Gazal; Junghare, Vivek; Khan, Mohammad...
#
#                created_date custom_fields  defined_type_metadata  \
# 2      2007-01-09T00:43:06Z            []                      3
# 4      2007-02-23T00:40:41Z            []                      3
# 9      2007-10-17T00:29:05Z            []                      3
# 10     2007-11-23T00:23:38Z            []                      3
# 11     2007-11-30T00:22:53Z            []                      3
# ...                     ...           ...                    ...
# 24204  2021-12-02T15:58:43Z            []                      3
# 24205  2021-12-02T15:59:13Z            []                      3
# 24206  2021-12-02T15:59:36Z            []                      3
# 24207  2021-12-02T15:59:52Z            []                      3
# 24210  2021-12-02T18:06:11Z            []                      3
#
#       defined_type_name_metadata  \
# 2                        dataset
# 4                        dataset
# 9                        dataset
# 10                       dataset
# 11                       dataset
# ...                          ...
# 24204                    dataset
# 24205                    dataset
# 24206                    dataset
# 24207                    dataset
# 24210                    dataset
#
#                                              description  \
# 2      <div><p>Machine learning approaches offer the ...
# 4                                    <p>(161 KB PDF)</p>
# 9      <div><h3>Background</h3><p>The availability of...
# 10     <div><p>The long-term health outcome of prenat...
# 11     <div><p>microRNAs (miRNAs) are important post-...
# ...                                                  ...
# 24204  <div>Supplementary Table 2.  Unsupervised lear...
# 24205  <div>Supplementary Table 3.  Unsupervised lear...
# 24206  <div>Supplementary Table 4.  Unsupervised lear...
# 24207  <div>Supplementary Table 5.  Unsupervised lear...
# 24210  Angiotensin\nconverting enzyme-I (ACE-I) is a ...
#
#                              doi_metadata embargo_date embargo_options  \
# 2            10.1371/journal.pbio.0050008         None              []
# 4      10.1371/journal.pcbi.0030020.sd001         None              []
# 9            10.1371/journal.pone.0001047         None              []
# 10           10.1371/journal.pgen.0030207         None              []
# 11           10.1371/journal.pcbi.0030238         None              []
# ...                                   ...          ...             ...
# 24204            10.25402/FON.17113517.v2         None              []
# 24205            10.25402/FON.17113523.v2         None              []
# 24206            10.25402/FON.17113529.v2         None              []
# 24207            10.25402/FON.17113550.v2         None              []
# 24210       10.1021/acs.jafc.1c04555.s001         None              []
#
#       embargo_reason embargo_title embargo_type  \
# 2                                          None
# 4                                          None
# 9                                          None
# 10                                         None
# 11                                         None
# ...              ...           ...          ...
# 24204                                      file
# 24205                                      file
# 24206                                      file
# 24207                                      file
# 24210                                      None
#
#                                             figshare_url  \
# 2      https://plos.figshare.com/articles/dataset/Lar...
# 4      https://plos.figshare.com/articles/dataset/Imp...
# 9      https://plos.figshare.com/articles/dataset/Mod...
# 10     https://plos.figshare.com/articles/dataset/Act...
# 11     https://plos.figshare.com/articles/dataset/Int...
# ...                                                  ...
# 24204  https://future-science-group.figshare.com/arti...
# 24205  https://future-science-group.figshare.com/arti...
# 24206  https://future-science-group.figshare.com/arti...
# 24207  https://future-science-group.figshare.com/arti...
# 24210  https://acs.figshare.com/articles/dataset/Anti...
#
#                                                    files funding funding_list  \
# 2      [{'id': 469682, 'name': 'Figure_S1.pdf', 'size...    None           []
# 4      [{'id': 468834, 'name': 'Protocol_S1.pdf', 'si...    None           []
# 9      [{'id': 465350, 'name': 'Text_S1.doc', 'size':...    None           []
# 10     [{'id': 463877, 'name': 'Figure_S1.pdf', 'size...    None           []
# 11     [{'id': 6649146, 'name': 'Dataset S1.TDS', 'si...    None           []
# ...                                                  ...     ...          ...
# 24204  [{'id': 31645340, 'name': 'Supplementary Table...    None           []
# 24205  [{'id': 31645343, 'name': 'Supplementary Table...    None           []
# 24206  [{'id': 31645349, 'name': 'Supplementary Table...    None           []
# 24207  [{'id': 31645355, 'name': 'Supplementary Table...    None           []
# 24210  [{'id': 31646025, 'name': 'jf1c04555_si_001.xl...    None           []
#
#        group_id_metadata handle_metadata  has_linked_file  is_confidential  \
# 2                  116.0                                0                0
# 4                  101.0                                0                0
# 9                  107.0                                0                0
# 10                  98.0                                0                0
# 11                 101.0                                0                0
# ...                  ...             ...              ...              ...
# 24204            21381.0                                0                0
# 24205            21381.0                                0                0
# 24206            21381.0                                0                0
# 24207            21381.0                                0                0
# 24210             2505.0                                0                0
#
#        is_embargoed  is_metadata_record  is_public  \
# 2                 0                   0          1
# 4                 0                   0          1
# 9                 0                   0          1
# 10                0                   0          1
# 11                0                   0          1
# ...             ...                 ...        ...
# 24204             0                   0          1
# 24205             0                   0          1
# 24206             0                   0          1
# 24207             0                   0          1
# 24210             0                   0          1
#
#                                                  license metadata_reason  \
# 2      {'value': 1, 'name': 'CC BY 4.0', 'url': 'http...
# 4      {'value': 1, 'name': 'CC BY 4.0', 'url': 'http...
# 9      {'value': 1, 'name': 'CC BY 4.0', 'url': 'http...
# 10     {'value': 1, 'name': 'CC BY 4.0', 'url': 'http...
# 11     {'value': 1, 'name': 'CC BY 4.0', 'url': 'http...
# ...                                                  ...             ...
# 24204  {'value': 12, 'name': 'CC BY-NC-ND 4.0', 'url'...
# 24205  {'value': 12, 'name': 'CC BY-NC-ND 4.0', 'url'...
# 24206  {'value': 12, 'name': 'CC BY-NC-ND 4.0', 'url'...
# 24207  {'value': 12, 'name': 'CC BY-NC-ND 4.0', 'url'...
# 24210  {'value': 10, 'name': 'CC BY-NC 4.0', 'url': '...
#
#               modified_date published_date_metadata references  \
# 2      2016-01-18T11:28:43Z    2007-01-09T00:43:06Z         []
# 4      2020-04-27T08:11:31Z    2007-02-23T00:40:41Z         []
# 9      2016-01-18T12:04:10Z    2007-10-17T00:29:05Z         []
# 10     2016-01-18T12:04:14Z    2007-11-23T00:23:38Z         []
# 11     2016-10-28T06:55:11Z    2007-11-30T00:22:53Z         []
# ...                     ...                     ...        ...
# 24204  2021-12-02T15:58:46Z    2021-12-02T15:58:43Z         []
# 24205  2021-12-02T15:59:15Z    2021-12-02T15:59:13Z         []
# 24206  2021-12-02T15:59:38Z    2021-12-02T15:59:36Z         []
# 24207  2021-12-02T15:59:54Z    2021-12-02T15:59:52Z         []
# 24210  2021-12-02T18:06:11Z    2021-12-02T18:06:11Z         []
#
#               resource_doi_metadata  \
# 2      10.1371/journal.pbio.0050008
# 4      10.1371/journal.pcbi.0030020
# 9      10.1371/journal.pone.0001047
# 10     10.1371/journal.pgen.0030207
# 11     10.1371/journal.pcbi.0030238
# ...                             ...
# 24204         10.2217/fon-2021-1059
# 24205         10.2217/fon-2021-1059
# 24206         10.2217/fon-2021-1059
# 24207         10.2217/fon-2021-1059
# 24210      10.1021/acs.jafc.1c04555
#
#                                  resource_title_metadata      size  status  \
# 2      Large-Scale Mapping and Validation of Escheric...   3358192  public
# 4      Improving the <em>Caenorhabditis elegans</em> ...         0  public
# 9      Module-Based Outcome Prediction Using Breast C...  12532568  public
# 10     Activation of Inflammation/NF-κB Signaling in ...  12846051  public
# 11     Intragenomic Matching Reveals a Huge Potential...   3756384  public
# ...                                                  ...       ...     ...
# 24204  Unsupervised learning of cross-modal mappings ...     77444  public
# 24205  Unsupervised learning of cross-modal mappings ...    185790  public
# 24206  Unsupervised learning of cross-modal mappings ...    137646  public
# 24207  Unsupervised learning of cross-modal mappings ...    109962  public
# 24210  Anti-hypertensive Peptide Predictor: A Machine...    153877  public
#
#                                                     tags  \
# 2      [large-scale, validation, transcriptional, com...
# 4                        [improving, genome, annotation]
# 9                      [module-based, cancer, compendia]
# 10     [activation, signaling, infants, arsenic-expos...
# 11     [support vector machine classification, target...
# ...                                                  ...
# 24204  [machine learning, gastric cancer, disease mod...
# 24205  [machine learning, gastric cancer, disease mod...
# 24206  [machine learning, gastric cancer, disease mod...
# 24207  [machine learning, gastric cancer, disease mod...
# 24210  [key therapeutic target, hypertensive peptide ...
#
#                                           thumb_metadata  \
# 2      https://s3-eu-west-1.amazonaws.com/ppreviews-p...
# 4      https://s3-eu-west-1.amazonaws.com/ppreviews-p...
# 9      https://s3-eu-west-1.amazonaws.com/ppreviews-p...
# 10     https://s3-eu-west-1.amazonaws.com/ppreviews-p...
# 11     https://s3-eu-west-1.amazonaws.com/ppreviews-p...
# ...                                                  ...
# 24204  https://s3-eu-west-1.amazonaws.com/ppreviews-f...
# 24205  https://s3-eu-west-1.amazonaws.com/ppreviews-f...
# 24206  https://s3-eu-west-1.amazonaws.com/ppreviews-f...
# 24207  https://s3-eu-west-1.amazonaws.com/ppreviews-f...
# 24210
#
#                                        timeline_metadata  \
# 2      {'posted': '2007-01-09T00:43:06', 'firstOnline...
# 4      {'posted': '2007-02-23T00:40:41', 'firstOnline...
# 9      {'posted': '2007-10-17T00:29:05', 'firstOnline...
# 10     {'posted': '2007-11-23T00:23:38', 'firstOnline...
# 11     {'posted': '2007-11-30T00:22:53', 'firstOnline...
# ...                                                  ...
# 24204  {'posted': '2021-12-02T15:58:43', 'firstOnline...
# 24205  {'posted': '2021-12-02T15:59:13', 'firstOnline...
# 24206  {'posted': '2021-12-02T15:59:36', 'firstOnline...
# 24207  {'posted': '2021-12-02T15:59:52', 'firstOnline...
# 24210  {'posted': '2021-12-02T18:06:11', 'publisherPu...
#
#                                           title_metadata  \
# 2      Large-Scale Mapping and Validation of Escheric...
# 4      Data Preparation Protocols, Additional Results...
# 9      Module-Based Outcome Prediction Using Breast C...
# 10     Activation of Inflammation/NF-κB Signaling in ...
# 11     Intragenomic Matching Reveals a Huge Potential...
# ...                                                  ...
# 24204  Supplementary Table 2: Unsupervised learning o...
# 24205  Supplementary Table 3: Unsupervised learning o...
# 24206  Supplementary Table 4: Unsupervised learning o...
# 24207  Supplementary Table 5: Unsupervised learning o...
# 24210  Anti-hypertensive Peptide Predictor: A Machine...
#
#                                         url_metadata  \
# 2        https://api.figshare.com/v2/articles/152586
# 4        https://api.figshare.com/v2/articles/152441
# 9        https://api.figshare.com/v2/articles/151745
# 10       https://api.figshare.com/v2/articles/151418
# 11       https://api.figshare.com/v2/articles/151373
# ...                                              ...
# 24204  https://api.figshare.com/v2/articles/17113517
# 24205  https://api.figshare.com/v2/articles/17113523
# 24206  https://api.figshare.com/v2/articles/17113529
# 24207  https://api.figshare.com/v2/articles/17113550
# 24210  https://api.figshare.com/v2/articles/17114094
#
#                                 url_private_api_metadata  \
# 2      https://api.figshare.com/v2/account/articles/1...
# 4      https://api.figshare.com/v2/account/articles/1...
# 9      https://api.figshare.com/v2/account/articles/1...
# 10     https://api.figshare.com/v2/account/articles/1...
# 11     https://api.figshare.com/v2/account/articles/1...
# ...                                                  ...
# 24204  https://api.figshare.com/v2/account/articles/1...
# 24205  https://api.figshare.com/v2/account/articles/1...
# 24206  https://api.figshare.com/v2/account/articles/1...
# 24207  https://api.figshare.com/v2/account/articles/1...
# 24210  https://api.figshare.com/v2/account/articles/1...
#
#                             url_private_html_metadata  \
# 2        https://figshare.com/account/articles/152586
# 4        https://figshare.com/account/articles/152441
# 9        https://figshare.com/account/articles/151745
# 10       https://figshare.com/account/articles/151418
# 11       https://figshare.com/account/articles/151373
# ...                                               ...
# 24204  https://figshare.com/account/articles/17113517
# 24205  https://figshare.com/account/articles/17113523
# 24206  https://figshare.com/account/articles/17113529
# 24207  https://figshare.com/account/articles/17113550
# 24210  https://figshare.com/account/articles/17114094
#
#                              url_public_api_metadata  \
# 2        https://api.figshare.com/v2/articles/152586
# 4        https://api.figshare.com/v2/articles/152441
# 9        https://api.figshare.com/v2/articles/151745
# 10       https://api.figshare.com/v2/articles/151418
# 11       https://api.figshare.com/v2/articles/151373
# ...                                              ...
# 24204  https://api.figshare.com/v2/articles/17113517
# 24205  https://api.figshare.com/v2/articles/17113523
# 24206  https://api.figshare.com/v2/articles/17113529
# 24207  https://api.figshare.com/v2/articles/17113550
# 24210  https://api.figshare.com/v2/articles/17114094
#
#                                 url_public_html_metadata  version
# 2      https://plos.figshare.com/articles/dataset/Lar...        1
# 4      https://plos.figshare.com/articles/dataset/Imp...        1
# 9      https://plos.figshare.com/articles/dataset/Mod...        1
# 10     https://plos.figshare.com/articles/dataset/Act...        1
# 11     https://plos.figshare.com/articles/dataset/Int...        1
# ...                                                  ...      ...
# 24204  https://future-science-group.figshare.com/arti...        2
# 24205  https://future-science-group.figshare.com/arti...        2
# 24206  https://future-science-group.figshare.com/arti...        2
# 24207  https://future-science-group.figshare.com/arti...        2
# 24210  https://acs.figshare.com/articles/dataset/Anti...        1
#
# [10359 rows x 64 columns]

# %% [markdown]
# ## 1. How many total objects (not just records) are in our main dataset extracts for each repository?
# **Property:** unique_identifier

# %%
ids = df.FigshareArticlesCrosswalk.unique_identifier
ids
# Out:
# 2          152586
# 4          152441
# 9          151745
# 10         151418
# 11         151373
#            ...
# 24204    17113517
# 24205    17113523
# 24206    17113529
# 24207    17113550
# 24210    17114094
# Name: id, Length: 10359, dtype: int64

# %%
ids.nunique()
# Out:
# 10347

# %%
print(f'There are {len(ids)} items in the Figshare extract, with {ids.nunique()} unique IDs.')
# Out:
# There are 10359 items in the Figshare extract, with 10347 unique IDs.

# %%
#most have 1 row, 9 have 4 row instances
ids.value_counts().value_counts()
# Out:
# 1    10343
# 4        4
# Name: id, dtype: int64

# %%
#look into these duplicate IDs
ids.value_counts()
# Out:
# 8832509     4
# 14099231    4
# 14254089    4
# 12618089    4
# 13517543    1
#            ..
# 8200526     1
# 8206505     1
# 8143394     1
# 8207012     1
# 17114094    1
# Name: id, Length: 10347, dtype: int64

# %%
fig_dupes = df.loc[df['id'] == 8832509]
fig_dupes
# Out:
#            id                                       title_search  \
# 9003  8832509  Data and R code for "The paleoclimatic footpri...
# 9004  8832509  Data and R code for "The paleoclimatic footpri...
# 9005  8832509  Data and R code for "The paleoclimatic footpri...
# 9006  8832509  Data and R code for "The paleoclimatic footpri...
#
#                           doi_search handle_search  \
# 9003  10.6084/m9.figshare.8832509.v2
# 9004  10.6084/m9.figshare.8832509.v2
# 9005  10.6084/m9.figshare.8832509.v2
# 9006  10.6084/m9.figshare.8832509.v2
#
#                                         url_search published_date_search  \
# 9003  https://api.figshare.com/v2/articles/8832509  2019-08-16T04:34:07Z
# 9004  https://api.figshare.com/v2/articles/8832509  2019-08-16T04:34:07Z
# 9005  https://api.figshare.com/v2/articles/8832509  2019-08-16T04:34:07Z
# 9006  https://api.figshare.com/v2/articles/8832509  2019-08-16T04:34:07Z
#
#      thumb_search  defined_type_search defined_type_name_search  \
# 9003                                 3                  dataset
# 9004                                 3                  dataset
# 9005                                 3                  dataset
# 9006                                 3                  dataset
#
#       group_id_search                             url_private_api_search  \
# 9003              NaN  https://api.figshare.com/v2/account/articles/8...
# 9004              NaN  https://api.figshare.com/v2/account/articles/8...
# 9005              NaN  https://api.figshare.com/v2/account/articles/8...
# 9006              NaN  https://api.figshare.com/v2/account/articles/8...
#
#                              url_public_api_search  \
# 9003  https://api.figshare.com/v2/articles/8832509
# 9004  https://api.figshare.com/v2/articles/8832509
# 9005  https://api.figshare.com/v2/articles/8832509
# 9006  https://api.figshare.com/v2/articles/8832509
#
#                             url_private_html_search  \
# 9003  https://figshare.com/account/articles/8832509
# 9004  https://figshare.com/account/articles/8832509
# 9005  https://figshare.com/account/articles/8832509
# 9006  https://figshare.com/account/articles/8832509
#
#                                  url_public_html_search  \
# 9003  https://figshare.com/articles/dataset/Data_and...
# 9004  https://figshare.com/articles/dataset/Data_and...
# 9005  https://figshare.com/articles/dataset/Data_and...
# 9006  https://figshare.com/articles/dataset/Data_and...
#
#                                         timeline_search resource_title_search  \
# 9003  {'posted': '2019-08-16T04:34:07', 'firstOnline...
# 9004  {'posted': '2019-08-16T04:34:07', 'firstOnline...
# 9005  {'posted': '2019-08-16T04:34:07', 'firstOnline...
# 9006  {'posted': '2019-08-16T04:34:07', 'firstOnline...
#
#      resource_doi_search  search_page publish_query  \
# 9003                                9    1950-01-01
# 9004                                9    1950-01-01
# 9005                                1    2019-08-16
# 9006                                1    2019-08-16
#
#                                                 authors  \
# 9003  [{'id': 3861649, 'full_name': 'Jinzhi Ding', '...
# 9004  [{'id': 3861649, 'full_name': 'Jinzhi Ding', '...
# 9005  [{'id': 3861649, 'full_name': 'Jinzhi Ding', '...
# 9006  [{'id': 3861649, 'full_name': 'Jinzhi Ding', '...
#
#                                              categories  \
# 9003  [{'id': 266, 'title': 'Carbon Sequestration Sc...
# 9004  [{'id': 266, 'title': 'Carbon Sequestration Sc...
# 9005  [{'id': 266, 'title': 'Carbon Sequestration Sc...
# 9006  [{'id': 266, 'title': 'Carbon Sequestration Sc...
#
#                                                citation confidential_reason  \
# 9003  Ding, Jinzhi; Wang, Tao; Piao, Shilong; Smith,...
# 9004  Ding, Jinzhi; Wang, Tao; Piao, Shilong; Smith,...
# 9005  Ding, Jinzhi; Wang, Tao; Piao, Shilong; Smith,...
# 9006  Ding, Jinzhi; Wang, Tao; Piao, Shilong; Smith,...
#
#               created_date custom_fields  defined_type_metadata  \
# 9003  2019-08-16T04:34:07Z            []                      3
# 9004  2019-08-16T04:34:07Z            []                      3
# 9005  2019-08-16T04:34:07Z            []                      3
# 9006  2019-08-16T04:34:07Z            []                      3
#
#      defined_type_name_metadata  \
# 9003                    dataset
# 9004                    dataset
# 9005                    dataset
# 9006                    dataset
#
#                                             description  \
# 9003  A new estimate of  Tibetan soil carbon pool, a...
# 9004  A new estimate of  Tibetan soil carbon pool, a...
# 9005  A new estimate of  Tibetan soil carbon pool, a...
# 9006  A new estimate of  Tibetan soil carbon pool, a...
#
#                         doi_metadata embargo_date embargo_options  \
# 9003  10.6084/m9.figshare.8832509.v2   2019-11-09              []
# 9004  10.6084/m9.figshare.8832509.v2   2019-11-09              []
# 9005  10.6084/m9.figshare.8832509.v2   2019-11-09              []
# 9006  10.6084/m9.figshare.8832509.v2   2019-11-09              []
#
#      embargo_reason embargo_title embargo_type  \
# 9003                                      file
# 9004                                      file
# 9005                                      file
# 9006                                      file
#
#                                            figshare_url  \
# 9003  https://figshare.com/articles/dataset/Data_and...
# 9004  https://figshare.com/articles/dataset/Data_and...
# 9005  https://figshare.com/articles/dataset/Data_and...
# 9006  https://figshare.com/articles/dataset/Data_and...
#
#                                                   files  \
# 9003  [{'id': 16174970, 'name': 'Tibetan soil carbon...
# 9004  [{'id': 16174970, 'name': 'Tibetan soil carbon...
# 9005  [{'id': 16174970, 'name': 'Tibetan soil carbon...
# 9006  [{'id': 16174970, 'name': 'Tibetan soil carbon...
#
#                                                 funding  \
# 9003  the Strategic Priority Research Program (A) of...
# 9004  the Strategic Priority Research Program (A) of...
# 9005  the Strategic Priority Research Program (A) of...
# 9006  the Strategic Priority Research Program (A) of...
#
#                                            funding_list  group_id_metadata  \
# 9003  [{'id': 14948300, 'title': 'the Strategic Prio...                NaN
# 9004  [{'id': 14948300, 'title': 'the Strategic Prio...                NaN
# 9005  [{'id': 14948300, 'title': 'the Strategic Prio...                NaN
# 9006  [{'id': 14948300, 'title': 'the Strategic Prio...                NaN
#
#      handle_metadata  has_linked_file  is_confidential  is_embargoed  \
# 9003                                0                0             0
# 9004                                0                0             0
# 9005                                0                0             0
# 9006                                0                0             0
#
#       is_metadata_record  is_public  \
# 9003                   0          1
# 9004                   0          1
# 9005                   0          1
# 9006                   0          1
#
#                                                 license metadata_reason  \
# 9003  {'value': 1, 'name': 'CC BY 4.0', 'url': 'http...
# 9004  {'value': 1, 'name': 'CC BY 4.0', 'url': 'http...
# 9005  {'value': 1, 'name': 'CC BY 4.0', 'url': 'http...
# 9006  {'value': 1, 'name': 'CC BY 4.0', 'url': 'http...
#
#              modified_date published_date_metadata references  \
# 9003  2019-08-16T04:34:07Z    2019-08-16T04:34:07Z         []
# 9004  2019-08-16T04:34:07Z    2019-08-16T04:34:07Z         []
# 9005  2019-08-16T04:34:07Z    2019-08-16T04:34:07Z         []
# 9006  2019-08-16T04:34:07Z    2019-08-16T04:34:07Z         []
#
#      resource_doi_metadata resource_title_metadata     size  status  \
# 9003                  None                    None  1336299  public
# 9004                  None                    None  1336299  public
# 9005                  None                    None  1336299  public
# 9006                  None                    None  1336299  public
#
#                                                    tags thumb_metadata  \
# 9003  [soil carbon stock, alpine permafrost, Tibetan...
# 9004  [soil carbon stock, alpine permafrost, Tibetan...
# 9005  [soil carbon stock, alpine permafrost, Tibetan...
# 9006  [soil carbon stock, alpine permafrost, Tibetan...
#
#                                       timeline_metadata  \
# 9003  {'posted': '2019-08-16T04:34:07', 'firstOnline...
# 9004  {'posted': '2019-08-16T04:34:07', 'firstOnline...
# 9005  {'posted': '2019-08-16T04:34:07', 'firstOnline...
# 9006  {'posted': '2019-08-16T04:34:07', 'firstOnline...
#
#                                          title_metadata  \
# 9003  Data and R code for "The paleoclimatic footpri...
# 9004  Data and R code for "The paleoclimatic footpri...
# 9005  Data and R code for "The paleoclimatic footpri...
# 9006  Data and R code for "The paleoclimatic footpri...
#
#                                       url_metadata  \
# 9003  https://api.figshare.com/v2/articles/8832509
# 9004  https://api.figshare.com/v2/articles/8832509
# 9005  https://api.figshare.com/v2/articles/8832509
# 9006  https://api.figshare.com/v2/articles/8832509
#
#                                url_private_api_metadata  \
# 9003  https://api.figshare.com/v2/account/articles/8...
# 9004  https://api.figshare.com/v2/account/articles/8...
# 9005  https://api.figshare.com/v2/account/articles/8...
# 9006  https://api.figshare.com/v2/account/articles/8...
#
#                           url_private_html_metadata  \
# 9003  https://figshare.com/account/articles/8832509
# 9004  https://figshare.com/account/articles/8832509
# 9005  https://figshare.com/account/articles/8832509
# 9006  https://figshare.com/account/articles/8832509
#
#                            url_public_api_metadata  \
# 9003  https://api.figshare.com/v2/articles/8832509
# 9004  https://api.figshare.com/v2/articles/8832509
# 9005  https://api.figshare.com/v2/articles/8832509
# 9006  https://api.figshare.com/v2/articles/8832509
#
#                                url_public_html_metadata  version
# 9003  https://figshare.com/articles/dataset/Data_and...        2
# 9004  https://figshare.com/articles/dataset/Data_and...        2
# 9005  https://figshare.com/articles/dataset/Data_and...        2
# 9006  https://figshare.com/articles/dataset/Data_and...        2

# %%
#compare rows to see if identical
fig1 = fig_dupes.iloc[0]
fig2 = fig_dupes.iloc[1]
fig3 = fig_dupes.iloc[2]
fig4 = fig_dupes.iloc[3]

print(fig1.equals(fig2))
print(fig2.equals(fig3))
print(fig3.equals(fig4))
# Out:
# True
# False
# True

# %%
#So first two instances are identical, and latter two instances are identical, but they differ from each other
#can at least narrow down to 2 instances rather than 4
#would need to dig deeper into how they differ, since at a glance, they look the same

# %%
fig_diffs = fig1 == fig4
fig_diffs
# Out:
# id                             True
# title_search                   True
# doi_search                     True
# handle_search                  True
# url_search                     True
# published_date_search          True
# thumb_search                   True
# defined_type_search            True
# defined_type_name_search       True
# group_id_search               False
# url_private_api_search         True
# url_public_api_search          True
# url_private_html_search        True
# url_public_html_search         True
# timeline_search                True
# resource_title_search          True
# resource_doi_search            True
# search_page                   False
# publish_query                 False
# authors                        True
# categories                     True
# citation                       True
# confidential_reason            True
# created_date                   True
# custom_fields                  True
# defined_type_metadata          True
# defined_type_name_metadata     True
# description                    True
# doi_metadata                   True
# embargo_date                   True
# embargo_options                True
# embargo_reason                 True
# embargo_title                  True
# embargo_type                   True
# figshare_url                   True
# files                          True
# funding                        True
# funding_list                   True
# group_id_metadata             False
# handle_metadata                True
# has_linked_file                True
# is_confidential                True
# is_embargoed                   True
# is_metadata_record             True
# is_public                      True
# license                        True
# metadata_reason                True
# modified_date                  True
# published_date_metadata        True
# references                     True
# resource_doi_metadata         False
# resource_title_metadata       False
# size                           True
# status                         True
# tags                           True
# thumb_metadata                 True
# timeline_metadata              True
# title_metadata                 True
# url_metadata                   True
# url_private_api_metadata       True
# url_private_html_metadata      True
# url_public_api_metadata        True
# url_public_html_metadata       True
# version                        True
# dtype: bool

# %%
index_diffs = fig_diffs[fig_diffs == False]
index_diffs
# Out:
# group_id_search            False
# search_page                False
# publish_query              False
# group_id_metadata          False
# resource_doi_metadata      False
# resource_title_metadata    False
# dtype: bool

# %%
index_diffs_str = index_diffs.index.tolist()
index_diffs_str
# Out:
# ['group_id_search',
#  'search_page',
#  'publish_query',
#  'group_id_metadata',
#  'resource_doi_metadata',
#  'resource_title_metadata']

# %%
fig1[index_diffs_str].dropna()
# Out:
# search_page               9
# publish_query    1950-01-01
# Name: 9003, dtype: object

# %%
fig4[index_diffs_str].dropna()
# Out:
# search_page               1
# publish_query    2019-08-16
# Name: 9006, dtype: object

# %%
#we don't use search_page for anything, so can ignore
#besides date field, other variations are None or NaN, so can ignore
#as with other repo duplicates, we likely want to keep most recent published, when same id

# %%
#subset to view only the duplicate ids
dupes_all = ids.value_counts().to_frame()
dupes_all = dupes_all[dupes_all['id'] == 4]
dupes_all
# Out:
#           id
# 8832509    4
# 14099231   4
# 14254089   4
# 12618089   4

# %%
dupes_all_ids = dupes_all.index.to_list()
dupes_all_ids
# Out:
# [8832509, 14099231, 14254089, 12618089]

# %%
dupes_df = df[df.id.isin(dupes_all_ids)].sort_values(['id', 'search_page', 'publish_query', 'embargo_date'])
dupes_df[['id', 'search_page', 'publish_query', 'embargo_date']]
# Out:
#              id  search_page publish_query embargo_date
# 9005    8832509            1    2019-08-16   2019-11-09
# 9006    8832509            1    2019-08-16   2019-11-09
# 9003    8832509            9    1950-01-01   2019-11-09
# 9004    8832509            9    1950-01-01   2019-11-09
# 13009  12618089            4    2019-08-16         None
# 13010  12618089            4    2019-08-16         None
# 13011  12618089            5    2019-08-16         None
# 13012  12618089            5    2019-08-16         None
# 3136   14099231            1    2019-08-16         None
# 3137   14099231            1    2019-08-16         None
# 3134   14099231            4    1950-01-01         None
# 3135   14099231            4    1950-01-01         None
# 18011  14254089            1    2021-03-21         None
# 18012  14254089            1    2021-03-21         None
# 18009  14254089            9    2019-08-16         None
# 18010  14254089            9    2019-08-16         None

# %%
#there's no way the 1950s dates are accurate
#and can ignore all the None embargo dates
#so difference is in search_page and publish_query

# %%
#group by id, sort by descending date, and select last date
df_use = df.sort_values(['id', 'publish_query'], ascending = False).groupby('id').nth(0).reset_index()
df_use
# Out:
#              id                                       title_search  \
# 0        114867  Genome-Wide Screens for <em>In Vivo</em> Tinma...
# 1        116703  PROSPER: An Integrated Feature-Based Tool for ...
# 2        116813  Exploiting Genomic Knowledge in Optimising Mol...
# 3        117032  Text S1 - <em>e</em>Thread: A Highly Optimized...
# 4        117391  A Machine Learning Approach for Identifying Am...
# ...         ...                                                ...
# 10342  17113517  Supplementary Table 2: Unsupervised learning o...
# 10343  17113523  Supplementary Table 3: Unsupervised learning o...
# 10344  17113529  Supplementary Table 4: Unsupervised learning o...
# 10345  17113550  Supplementary Table 5: Unsupervised learning o...
# 10346  17114094  Anti-hypertensive Peptide Predictor: A Machine...
#
#                               doi_search handle_search  \
# 0           10.1371/journal.pgen.1003195
# 1           10.1371/journal.pone.0050300
# 2           10.1371/journal.pone.0048862
# 3      10.1371/journal.pone.0050200.s001
# 4           10.1371/journal.pone.0049538
# ...                                  ...           ...
# 10342           10.25402/fon.17113517.v2
# 10343           10.25402/fon.17113523.v2
# 10344           10.25402/fon.17113529.v2
# 10345           10.25402/fon.17113550.v2
# 10346      10.1021/acs.jafc.1c04555.s001
#
#                                           url_search published_date_search  \
# 0        https://api.figshare.com/v2/articles/114867  2013-01-10T01:21:07Z
# 1        https://api.figshare.com/v2/articles/116703  2012-11-29T01:51:43Z
# 2        https://api.figshare.com/v2/articles/116813  2012-11-21T01:53:33Z
# 3        https://api.figshare.com/v2/articles/117032  2012-11-21T01:57:12Z
# 4        https://api.figshare.com/v2/articles/117391  2012-11-14T02:03:11Z
# ...                                              ...                   ...
# 10342  https://api.figshare.com/v2/articles/17113517  2021-12-02T15:58:43Z
# 10343  https://api.figshare.com/v2/articles/17113523  2021-12-02T15:59:13Z
# 10344  https://api.figshare.com/v2/articles/17113529  2021-12-02T15:59:36Z
# 10345  https://api.figshare.com/v2/articles/17113550  2021-12-02T15:59:52Z
# 10346  https://api.figshare.com/v2/articles/17114094  2021-12-02T18:06:11Z
#
#                                             thumb_search  defined_type_search  \
# 0      https://s3-eu-west-1.amazonaws.com/ppreviews-p...                    3
# 1      https://s3-eu-west-1.amazonaws.com/ppreviews-p...                    3
# 2                                                                           3
# 3      https://s3-eu-west-1.amazonaws.com/ppreviews-p...                    3
# 4      https://s3-eu-west-1.amazonaws.com/ppreviews-p...                    3
# ...                                                  ...                  ...
# 10342  https://s3-eu-west-1.amazonaws.com/ppreviews-f...                    3
# 10343  https://s3-eu-west-1.amazonaws.com/ppreviews-f...                    3
# 10344  https://s3-eu-west-1.amazonaws.com/ppreviews-f...                    3
# 10345  https://s3-eu-west-1.amazonaws.com/ppreviews-f...                    3
# 10346                                                                       3
#
#       defined_type_name_search  group_id_search  \
# 0                      dataset             98.0
# 1                      dataset            107.0
# 2                      dataset            107.0
# 3                      dataset            107.0
# 4                      dataset            107.0
# ...                        ...              ...
# 10342                  dataset          21381.0
# 10343                  dataset          21381.0
# 10344                  dataset          21381.0
# 10345                  dataset          21381.0
# 10346                  dataset           2505.0
#
#                                   url_private_api_search  \
# 0      https://api.figshare.com/v2/account/articles/1...
# 1      https://api.figshare.com/v2/account/articles/1...
# 2      https://api.figshare.com/v2/account/articles/1...
# 3      https://api.figshare.com/v2/account/articles/1...
# 4      https://api.figshare.com/v2/account/articles/1...
# ...                                                  ...
# 10342  https://api.figshare.com/v2/account/articles/1...
# 10343  https://api.figshare.com/v2/account/articles/1...
# 10344  https://api.figshare.com/v2/account/articles/1...
# 10345  https://api.figshare.com/v2/account/articles/1...
# 10346  https://api.figshare.com/v2/account/articles/1...
#
#                                url_public_api_search  \
# 0        https://api.figshare.com/v2/articles/114867
# 1        https://api.figshare.com/v2/articles/116703
# 2        https://api.figshare.com/v2/articles/116813
# 3        https://api.figshare.com/v2/articles/117032
# 4        https://api.figshare.com/v2/articles/117391
# ...                                              ...
# 10342  https://api.figshare.com/v2/articles/17113517
# 10343  https://api.figshare.com/v2/articles/17113523
# 10344  https://api.figshare.com/v2/articles/17113529
# 10345  https://api.figshare.com/v2/articles/17113550
# 10346  https://api.figshare.com/v2/articles/17114094
#
#                               url_private_html_search  \
# 0        https://figshare.com/account/articles/114867
# 1        https://figshare.com/account/articles/116703
# 2        https://figshare.com/account/articles/116813
# 3        https://figshare.com/account/articles/117032
# 4        https://figshare.com/account/articles/117391
# ...                                               ...
# 10342  https://figshare.com/account/articles/17113517
# 10343  https://figshare.com/account/articles/17113523
# 10344  https://figshare.com/account/articles/17113529
# 10345  https://figshare.com/account/articles/17113550
# 10346  https://figshare.com/account/articles/17114094
#
#                                   url_public_html_search  \
# 0      https://plos.figshare.com/articles/dataset/Gen...
# 1      https://plos.figshare.com/articles/dataset/PRO...
# 2      https://plos.figshare.com/articles/dataset/Exp...
# 3      https://plos.figshare.com/articles/dataset/_e_...
# 4      https://plos.figshare.com/articles/dataset/A_M...
# ...                                                  ...
# 10342  https://future-science-group.figshare.com/arti...
# 10343  https://future-science-group.figshare.com/arti...
# 10344  https://future-science-group.figshare.com/arti...
# 10345  https://future-science-group.figshare.com/arti...
# 10346  https://acs.figshare.com/articles/dataset/Anti...
#
#                                          timeline_search  \
# 0      {'posted': '2013-01-10T01:21:07', 'firstOnline...
# 1      {'posted': '2012-11-29T01:51:43', 'firstOnline...
# 2      {'posted': '2012-11-21T01:53:33', 'firstOnline...
# 3      {'posted': '2012-11-21T01:57:12', 'firstOnline...
# 4      {'posted': '2012-11-14T02:03:11', 'firstOnline...
# ...                                                  ...
# 10342  {'posted': '2021-12-02T15:58:43', 'firstOnline...
# 10343  {'posted': '2021-12-02T15:59:13', 'firstOnline...
# 10344  {'posted': '2021-12-02T15:59:36', 'firstOnline...
# 10345  {'posted': '2021-12-02T15:59:52', 'firstOnline...
# 10346  {'posted': '2021-12-02T18:06:11', 'publisherPu...
#
#                                    resource_title_search  \
# 0      Genome-Wide Screens for <em>In Vivo</em> Tinma...
# 1      PROSPER: An Integrated Feature-Based Tool for ...
# 2      Exploiting Genomic Knowledge in Optimising Mol...
# 3      <em>e</em>Thread: A Highly Optimized Machine L...
# 4      A Machine Learning Approach for Identifying Am...
# ...                                                  ...
# 10342  Unsupervised learning of cross-modal mappings ...
# 10343  Unsupervised learning of cross-modal mappings ...
# 10344  Unsupervised learning of cross-modal mappings ...
# 10345  Unsupervised learning of cross-modal mappings ...
# 10346  Anti-hypertensive Peptide Predictor: A Machine...
#
#                 resource_doi_search  search_page publish_query  \
# 0      10.1371/journal.pgen.1003195            1    1950-01-01
# 1      10.1371/journal.pone.0050300            1    1950-01-01
# 2      10.1371/journal.pone.0048862            1    1950-01-01
# 3      10.1371/journal.pone.0050200            1    1950-01-01
# 4      10.1371/journal.pone.0049538            1    1950-01-01
# ...                             ...          ...           ...
# 10342         10.2217/fon-2021-1059            7    2021-03-21
# 10343         10.2217/fon-2021-1059            7    2021-03-21
# 10344         10.2217/fon-2021-1059            7    2021-03-21
# 10345         10.2217/fon-2021-1059            7    2021-03-21
# 10346      10.1021/acs.jafc.1c04555            7    2021-03-21
#
#                                                  authors  \
# 0      [{'id': 65601, 'full_name': 'Hong Jin', 'is_ac...
# 1      [{'id': 59322, 'full_name': 'Jiangning Song', ...
# 2      [{'id': 116761, 'full_name': 'Steve O'Hagan', ...
# 3      [{'id': 119287, 'full_name': 'Michal Brylinski...
# 4      [{'id': 120312, 'full_name': 'Alexander G. Hol...
# ...                                                  ...
# 10342  [{'id': 511385, 'full_name': 'Jianmin Xu', 'is...
# 10343  [{'id': 511385, 'full_name': 'Jianmin Xu', 'is...
# 10344  [{'id': 511385, 'full_name': 'Jianmin Xu', 'is...
# 10345  [{'id': 511385, 'full_name': 'Jianmin Xu', 'is...
# 10346  [{'id': 8441022, 'full_name': 'Gazal Kalyan', ...
#
#                                               categories  \
# 0      [{'id': 13, 'title': 'Genetics', 'parent_id': ...
# 1      [{'id': 52, 'title': 'Information and Computin...
# 2      [{'id': 21, 'title': 'Biotechnology', 'parent_...
# 3      [{'id': 52, 'title': 'Information and Computin...
# 4      [{'id': 48, 'title': 'Biological Sciences', 'p...
# ...                                                  ...
# 10342  [{'id': 387, 'title': 'Solid Tumours', 'parent...
# 10343  [{'id': 387, 'title': 'Solid Tumours', 'parent...
# 10344  [{'id': 387, 'title': 'Solid Tumours', 'parent...
# 10345  [{'id': 387, 'title': 'Solid Tumours', 'parent...
# 10346  [{'id': 4, 'title': 'Biochemistry', 'parent_id...
#
#                                                 citation confidential_reason  \
# 0      Jin, Hong; Stojnic, Robert; Adryan, Boris; Ozd...
# 1      Song, Jiangning; Tan, Hao; J. Perry, Andrew; A...
# 2      O'Hagan, Steve; Knowles, Joshua; Kell, Douglas...
# 3      Brylinski, Michal; Lingam, Daswanth (2015): Te...
# 4      G. Holman, Alexander; Gabuzda, Dana (2016): A ...
# ...                                                  ...                 ...
# 10342  Xu, Jianmin; Xu, Binghua; Li, Yipeng; Su, Zhij...
# 10343  Xu, Jianmin; Xu, Binghua; Li, Yipeng; Su, Zhij...
# 10344  Xu, Jianmin; Xu, Binghua; Li, Yipeng; Su, Zhij...
# 10345  Xu, Jianmin; Xu, Binghua; Li, Yipeng; Su, Zhij...
# 10346  Kalyan, Gazal; Junghare, Vivek; Khan, Mohammad...
#
#                created_date custom_fields  defined_type_metadata  \
# 0      2013-01-10T01:21:07Z            []                      3
# 1      2012-11-29T01:51:43Z            []                      3
# 2      2012-11-21T01:53:33Z            []                      3
# 3      2012-11-21T01:57:12Z            []                      3
# 4      2012-11-14T02:03:11Z            []                      3
# ...                     ...           ...                    ...
# 10342  2021-12-02T15:58:43Z            []                      3
# 10343  2021-12-02T15:59:13Z            []                      3
# 10344  2021-12-02T15:59:36Z            []                      3
# 10345  2021-12-02T15:59:52Z            []                      3
# 10346  2021-12-02T18:06:11Z            []                      3
#
#       defined_type_name_metadata  \
# 0                        dataset
# 1                        dataset
# 2                        dataset
# 3                        dataset
# 4                        dataset
# ...                          ...
# 10342                    dataset
# 10343                    dataset
# 10344                    dataset
# 10345                    dataset
# 10346                    dataset
#
#                                              description  \
# 0      <div><p>The NK homeodomain factor Tinman is a ...
# 1      <div><p>The ability to catalytically cleave pr...
# 2      <div><p>Comparatively few studies have address...
# 3      <p>\n            <b>Calculation of the burial ...
# 4      <div><p>The identification of nucleotide seque...
# ...                                                  ...
# 10342  <div>Supplementary Table 2.  Unsupervised lear...
# 10343  <div>Supplementary Table 3.  Unsupervised lear...
# 10344  <div>Supplementary Table 4.  Unsupervised lear...
# 10345  <div>Supplementary Table 5.  Unsupervised lear...
# 10346  Angiotensin\nconverting enzyme-I (ACE-I) is a ...
#
#                             doi_metadata embargo_date embargo_options  \
# 0           10.1371/journal.pgen.1003195         None              []
# 1           10.1371/journal.pone.0050300         None              []
# 2           10.1371/journal.pone.0048862         None              []
# 3      10.1371/journal.pone.0050200.s001         None              []
# 4           10.1371/journal.pone.0049538         None              []
# ...                                  ...          ...             ...
# 10342           10.25402/FON.17113517.v2         None              []
# 10343           10.25402/FON.17113523.v2         None              []
# 10344           10.25402/FON.17113529.v2         None              []
# 10345           10.25402/FON.17113550.v2         None              []
# 10346      10.1021/acs.jafc.1c04555.s001         None              []
#
#       embargo_reason embargo_title embargo_type  \
# 0                                          None
# 1                                          None
# 2                                          None
# 3                                          None
# 4                                          None
# ...              ...           ...          ...
# 10342                                      file
# 10343                                      file
# 10344                                      file
# 10345                                      file
# 10346                                      None
#
#                                             figshare_url  \
# 0      https://plos.figshare.com/articles/dataset/Gen...
# 1      https://plos.figshare.com/articles/dataset/PRO...
# 2      https://plos.figshare.com/articles/dataset/Exp...
# 3      https://plos.figshare.com/articles/dataset/_e_...
# 4      https://plos.figshare.com/articles/dataset/A_M...
# ...                                                  ...
# 10342  https://future-science-group.figshare.com/arti...
# 10343  https://future-science-group.figshare.com/arti...
# 10344  https://future-science-group.figshare.com/arti...
# 10345  https://future-science-group.figshare.com/arti...
# 10346  https://acs.figshare.com/articles/dataset/Anti...
#
#                                                    files funding funding_list  \
# 0      [{'id': 278296, 'name': 'Figure_S1.tif', 'size...    None           []
# 1      [{'id': 287843, 'name': 'Figure_S1.tif', 'size...    None           []
# 2      [{'id': 288459, 'name': 'File_S1.xlsx', 'size'...    None           []
# 3      [{'id': 289627, 'name': 'Text_S1.pdf', 'size':...    None           []
# 4      [{'id': 291521, 'name': 'Figure_S1.pdf', 'size...    None           []
# ...                                                  ...     ...          ...
# 10342  [{'id': 31645340, 'name': 'Supplementary Table...    None           []
# 10343  [{'id': 31645343, 'name': 'Supplementary Table...    None           []
# 10344  [{'id': 31645349, 'name': 'Supplementary Table...    None           []
# 10345  [{'id': 31645355, 'name': 'Supplementary Table...    None           []
# 10346  [{'id': 31646025, 'name': 'jf1c04555_si_001.xl...    None           []
#
#        group_id_metadata handle_metadata  has_linked_file  is_confidential  \
# 0                   98.0                                0                0
# 1                  107.0                                0                0
# 2                  107.0                                0                0
# 3                  107.0                                0                0
# 4                  107.0                                0                0
# ...                  ...             ...              ...              ...
# 10342            21381.0                                0                0
# 10343            21381.0                                0                0
# 10344            21381.0                                0                0
# 10345            21381.0                                0                0
# 10346             2505.0                                0                0
#
#        is_embargoed  is_metadata_record  is_public  \
# 0                 0                   0          1
# 1                 0                   0          1
# 2                 0                   0          1
# 3                 0                   0          1
# 4                 0                   0          1
# ...             ...                 ...        ...
# 10342             0                   0          1
# 10343             0                   0          1
# 10344             0                   0          1
# 10345             0                   0          1
# 10346             0                   0          1
#
#                                                  license metadata_reason  \
# 0      {'value': 1, 'name': 'CC BY 4.0', 'url': 'http...
# 1      {'value': 1, 'name': 'CC BY 4.0', 'url': 'http...
# 2      {'value': 1, 'name': 'CC BY 4.0', 'url': 'http...
# 3      {'value': 1, 'name': 'CC BY 4.0', 'url': 'http...
# 4      {'value': 1, 'name': 'CC BY 4.0', 'url': 'http...
# ...                                                  ...             ...
# 10342  {'value': 12, 'name': 'CC BY-NC-ND 4.0', 'url'...
# 10343  {'value': 12, 'name': 'CC BY-NC-ND 4.0', 'url'...
# 10344  {'value': 12, 'name': 'CC BY-NC-ND 4.0', 'url'...
# 10345  {'value': 12, 'name': 'CC BY-NC-ND 4.0', 'url'...
# 10346  {'value': 10, 'name': 'CC BY-NC 4.0', 'url': '...
#
#               modified_date published_date_metadata references  \
# 0      2016-01-19T11:42:14Z    2013-01-10T01:21:07Z         []
# 1      2012-11-29T01:51:51Z    2012-11-29T01:51:43Z         []
# 2      2016-01-19T09:42:08Z    2012-11-21T01:53:33Z         []
# 3      2020-04-25T08:25:26Z    2012-11-21T01:57:12Z         []
# 4      2016-01-19T09:42:00Z    2012-11-14T02:03:11Z         []
# ...                     ...                     ...        ...
# 10342  2021-12-02T15:58:46Z    2021-12-02T15:58:43Z         []
# 10343  2021-12-02T15:59:15Z    2021-12-02T15:59:13Z         []
# 10344  2021-12-02T15:59:38Z    2021-12-02T15:59:36Z         []
# 10345  2021-12-02T15:59:54Z    2021-12-02T15:59:52Z         []
# 10346  2021-12-02T18:06:11Z    2021-12-02T18:06:11Z         []
#
#               resource_doi_metadata  \
# 0      10.1371/journal.pgen.1003195
# 1      10.1371/journal.pone.0050300
# 2      10.1371/journal.pone.0048862
# 3      10.1371/journal.pone.0050200
# 4      10.1371/journal.pone.0049538
# ...                             ...
# 10342         10.2217/fon-2021-1059
# 10343         10.2217/fon-2021-1059
# 10344         10.2217/fon-2021-1059
# 10345         10.2217/fon-2021-1059
# 10346      10.1021/acs.jafc.1c04555
#
#                                  resource_title_metadata      size  status  \
# 0      Genome-Wide Screens for <em>In Vivo</em> Tinma...  51942464  public
# 1      PROSPER: An Integrated Feature-Based Tool for ...   4188905  public
# 2      Exploiting Genomic Knowledge in Optimising Mol...   1092903  public
# 3      <em>e</em>Thread: A Highly Optimized Machine L...         0  public
# 4      A Machine Learning Approach for Identifying Am...   2850456  public
# ...                                                  ...       ...     ...
# 10342  Unsupervised learning of cross-modal mappings ...     77444  public
# 10343  Unsupervised learning of cross-modal mappings ...    185790  public
# 10344  Unsupervised learning of cross-modal mappings ...    137646  public
# 10345  Unsupervised learning of cross-modal mappings ...    109962  public
# 10346  Anti-hypertensive Peptide Predictor: A Machine...    153877  public
#
#                                                     tags  \
# 0      [genome-wide, screens, tinman, binding, sites,...
# 1      [feature-based, predicting, protease, substrat...
# 2      [exploiting, genomic, optimising, molecular, b...
# 3      [optimized, learning-based, meta-threading, mo...
# 4      [identifying, amino, signatures, hiv, predicti...
# ...                                                  ...
# 10342  [machine learning, gastric cancer, disease mod...
# 10343  [machine learning, gastric cancer, disease mod...
# 10344  [machine learning, gastric cancer, disease mod...
# 10345  [machine learning, gastric cancer, disease mod...
# 10346  [key therapeutic target, hypertensive peptide ...
#
#                                           thumb_metadata  \
# 0      https://s3-eu-west-1.amazonaws.com/ppreviews-p...
# 1      https://s3-eu-west-1.amazonaws.com/ppreviews-p...
# 2
# 3      https://s3-eu-west-1.amazonaws.com/ppreviews-p...
# 4      https://s3-eu-west-1.amazonaws.com/ppreviews-p...
# ...                                                  ...
# 10342  https://s3-eu-west-1.amazonaws.com/ppreviews-f...
# 10343  https://s3-eu-west-1.amazonaws.com/ppreviews-f...
# 10344  https://s3-eu-west-1.amazonaws.com/ppreviews-f...
# 10345  https://s3-eu-west-1.amazonaws.com/ppreviews-f...
# 10346
#
#                                        timeline_metadata  \
# 0      {'posted': '2013-01-10T01:21:07', 'firstOnline...
# 1      {'posted': '2012-11-29T01:51:43', 'firstOnline...
# 2      {'posted': '2012-11-21T01:53:33', 'firstOnline...
# 3      {'posted': '2012-11-21T01:57:12', 'firstOnline...
# 4      {'posted': '2012-11-14T02:03:11', 'firstOnline...
# ...                                                  ...
# 10342  {'posted': '2021-12-02T15:58:43', 'firstOnline...
# 10343  {'posted': '2021-12-02T15:59:13', 'firstOnline...
# 10344  {'posted': '2021-12-02T15:59:36', 'firstOnline...
# 10345  {'posted': '2021-12-02T15:59:52', 'firstOnline...
# 10346  {'posted': '2021-12-02T18:06:11', 'publisherPu...
#
#                                           title_metadata  \
# 0      Genome-Wide Screens for <em>In Vivo</em> Tinma...
# 1      PROSPER: An Integrated Feature-Based Tool for ...
# 2      Exploiting Genomic Knowledge in Optimising Mol...
# 3      Text S1 - <em>e</em>Thread: A Highly Optimized...
# 4      A Machine Learning Approach for Identifying Am...
# ...                                                  ...
# 10342  Supplementary Table 2: Unsupervised learning o...
# 10343  Supplementary Table 3: Unsupervised learning o...
# 10344  Supplementary Table 4: Unsupervised learning o...
# 10345  Supplementary Table 5: Unsupervised learning o...
# 10346  Anti-hypertensive Peptide Predictor: A Machine...
#
#                                         url_metadata  \
# 0        https://api.figshare.com/v2/articles/114867
# 1        https://api.figshare.com/v2/articles/116703
# 2        https://api.figshare.com/v2/articles/116813
# 3        https://api.figshare.com/v2/articles/117032
# 4        https://api.figshare.com/v2/articles/117391
# ...                                              ...
# 10342  https://api.figshare.com/v2/articles/17113517
# 10343  https://api.figshare.com/v2/articles/17113523
# 10344  https://api.figshare.com/v2/articles/17113529
# 10345  https://api.figshare.com/v2/articles/17113550
# 10346  https://api.figshare.com/v2/articles/17114094
#
#                                 url_private_api_metadata  \
# 0      https://api.figshare.com/v2/account/articles/1...
# 1      https://api.figshare.com/v2/account/articles/1...
# 2      https://api.figshare.com/v2/account/articles/1...
# 3      https://api.figshare.com/v2/account/articles/1...
# 4      https://api.figshare.com/v2/account/articles/1...
# ...                                                  ...
# 10342  https://api.figshare.com/v2/account/articles/1...
# 10343  https://api.figshare.com/v2/account/articles/1...
# 10344  https://api.figshare.com/v2/account/articles/1...
# 10345  https://api.figshare.com/v2/account/articles/1...
# 10346  https://api.figshare.com/v2/account/articles/1...
#
#                             url_private_html_metadata  \
# 0        https://figshare.com/account/articles/114867
# 1        https://figshare.com/account/articles/116703
# 2        https://figshare.com/account/articles/116813
# 3        https://figshare.com/account/articles/117032
# 4        https://figshare.com/account/articles/117391
# ...                                               ...
# 10342  https://figshare.com/account/articles/17113517
# 10343  https://figshare.com/account/articles/17113523
# 10344  https://figshare.com/account/articles/17113529
# 10345  https://figshare.com/account/articles/17113550
# 10346  https://figshare.com/account/articles/17114094
#
#                              url_public_api_metadata  \
# 0        https://api.figshare.com/v2/articles/114867
# 1        https://api.figshare.com/v2/articles/116703
# 2        https://api.figshare.com/v2/articles/116813
# 3        https://api.figshare.com/v2/articles/117032
# 4        https://api.figshare.com/v2/articles/117391
# ...                                              ...
# 10342  https://api.figshare.com/v2/articles/17113517
# 10343  https://api.figshare.com/v2/articles/17113523
# 10344  https://api.figshare.com/v2/articles/17113529
# 10345  https://api.figshare.com/v2/articles/17113550
# 10346  https://api.figshare.com/v2/articles/17114094
#
#                                 url_public_html_metadata  version
# 0      https://plos.figshare.com/articles/dataset/Gen...        1
# 1      https://plos.figshare.com/articles/dataset/PRO...        1
# 2      https://plos.figshare.com/articles/dataset/Exp...        1
# 3      https://plos.figshare.com/articles/dataset/_e_...        1
# 4      https://plos.figshare.com/articles/dataset/A_M...        1
# ...                                                  ...      ...
# 10342  https://future-science-group.figshare.com/arti...        2
# 10343  https://future-science-group.figshare.com/arti...        2
# 10344  https://future-science-group.figshare.com/arti...        2
# 10345  https://future-science-group.figshare.com/arti...        2
# 10346  https://acs.figshare.com/articles/dataset/Anti...        1
#
# [10347 rows x 64 columns]

# %%
df_use[df_use.id.isin(dupes_all_ids)].sort_values(['id', 'publish_query'])[['id','publish_query']]
# Out:
#             id publish_query
# 3726   8832509    2019-08-16
# 5668  12618089    2019-08-16
# 7509  14099231    2019-08-16
# 7793  14254089    2021-03-21

# %%
#for matching other notebooks, rename 'df_use' back to 'df'
df = df_use

# %%
ids = df.FigshareArticlesCrosswalk.unique_identifier

# %%
print(f'There are {len(ids)} items in the Figshare extract after removing duplicates, with {ids.nunique()} unique IDs.')
# Out:
# There are 10347 items in the Figshare extract after removing duplicates, with 10347 unique IDs.

# %% [markdown]
# ## 2. See the "Licenses offered" tab in /Working documents/Licenses sheet for list of licenses by repo.
#
# ## Given the type(s) of license(s) offered by the repo, how many of each type is assigned?
# **Property:** License

# %%
licenses = df.FigshareArticlesCrosswalk.license
licenses
# Out:
# 0              CC BY 4.0
# 1              CC BY 4.0
# 2              CC BY 4.0
# 3              CC BY 4.0
# 4              CC BY 4.0
#               ...
# 10342    CC BY-NC-ND 4.0
# 10343    CC BY-NC-ND 4.0
# 10344    CC BY-NC-ND 4.0
# 10345    CC BY-NC-ND 4.0
# 10346       CC BY-NC 4.0
# Name: license, Length: 10347, dtype: object

# %%
license_counts = licenses.value_counts().to_frame()
license_counts['percent'] = license_counts['license']/len(licenses) * 100
license_counts
# Out:
#                                                     license    percent
# CC BY 4.0                                              8004  77.355755
# CC BY + CC0                                             918   8.872137
# CC BY-NC 4.0                                            880   8.504881
# CC0                                                     251   2.425824
# MIT                                                     140   1.353049
# GPL 3.0+                                                 45   0.434909
# Apache 2.0                                               27   0.260945
# CC BY-NC-ND 4.0                                          17   0.164299
# In Copyright                                             15   0.144970
# CC BY                                                     8   0.077317
# CC BY-NC-SA 4.0                                           8   0.077317
# CC BY-SA 4.0                                              8   0.077317
# GPL                                                       6   0.057988
# GPL 2.0+                                                  3   0.028994
# CC BY-NC 2.0                                              3   0.028994
# CC BY 3.0 US                                              3   0.028994
# 4TU General Terms of Use                                  2   0.019329
# Restricted Access                                         2   0.019329
# CC0 1.0 Universal (CC0 1.0) Public Domain Dedic...        2   0.019329
# Public Domain                                             1   0.009665
# CC BY-NC 3.0 US                                           1   0.009665
# BSD 3-Clause                                              1   0.009665
# CC BY-ND 4.0                                              1   0.009665
# ODC-By                                                    1   0.009665

# %% [markdown]
# ## 3. What is the mean number of characters (excluding whitespaces, if possible) per object?
# **Property:** Description
# **Related function:** `mean_characters`

# %%
description = df.FigshareArticlesCrosswalk.description
description
# Out:
# 0        <div><p>The NK homeodomain factor Tinman is a ...
# 1        <div><p>The ability to catalytically cleave pr...
# 2        <div><p>Comparatively few studies have address...
# 3        <p>\n            <b>Calculation of the burial ...
# 4        <div><p>The identification of nucleotide seque...
#                                ...
# 10342    <div>Supplementary Table 2.  Unsupervised lear...
# 10343    <div>Supplementary Table 3.  Unsupervised lear...
# 10344    <div>Supplementary Table 4.  Unsupervised lear...
# 10345    <div>Supplementary Table 5.  Unsupervised lear...
# 10346    Angiotensin\nconverting enzyme-I (ACE-I) is a ...
# Name: description, Length: 10347, dtype: object

# %%
description.describe()
# Out:
# count             10347
# unique             8146
# top       <p>(XLSX)</p>
# freq                 74
# Name: description, dtype: object

# %%
print(f'Number of null descriptions: {sum(description.isna())}')
# Out:
# Number of null descriptions: 0

# %%
print(f'{analysis.mean_characters(description)} mean characters')
# Out:
# 862.0527866437516 mean characters

# %% [markdown]
# ## 4. What is the mean number of characters (excluding whitespaces, if possible) per object?
# **Property:** Methods
# **Related function:** `mean_characters`

# %%
methods = df.FigshareArticlesCrosswalk.methods
methods

# %%
#confirm missing for this repo
print(df.FigshareArticlesCrosswalk.methods)
# Out:
# None

# %% [markdown]
# ## 5. What are the min and max publication dates for each repo?
#
# ## How many objects were published each year for each repo?
# **Property:** Publication date

# %%
publication_dates = df.FigshareArticlesCrosswalk.publication_date
publication_dates
# Out:
# 0        2016-01-19T11:42:14
# 1        2012-11-29T01:51:51
# 2        2016-01-19T09:42:08
# 3        2015-12-02T12:40:08
# 4        2016-01-19T09:42:00
#                 ...
# 10342    2021-12-02T15:12:45
# 10343    2021-12-02T15:12:45
# 10344    2021-12-02T15:12:45
# 10345    2021-12-02T15:12:45
# 10346    2021-12-02T18:06:11
# Name: timeline_metadata, Length: 10347, dtype: object

# %%
#min and max publication year
publication_dates.min(), publication_dates.max()
# Out:
# ('2011-11-03T00:28:42', '2021-12-02T18:06:11')

# %%
#objects per year
publication_dates.astype('datetime64').apply(lambda date: date.year).value_counts().sort_index()
# Out:
# 2011       1
# 2012       1
# 2013      10
# 2014      16
# 2015     467
# 2016     866
# 2017     442
# 2018    1089
# 2019    1582
# 2020    2470
# 2021    3403
# Name: timeline_metadata, dtype: int64

# %%
#export for plotting
pub_dates_export = publication_dates.astype('datetime64').apply(lambda date: date.year).value_counts().sort_index().to_frame()

# %%
#update column names
pub_dates_export_ready = pub_dates_export.reset_index(level=0)
pub_dates_export_ready.columns = ['year', 'count']

# %%
#add column with name of repo
pub_dates_export_ready['repo'] = 'figshare_subset'

# %%
pub_dates_export_ready
# Out:
#     year  count             repo
# 0   2011      1  figshare_subset
# 1   2012      1  figshare_subset
# 2   2013     10  figshare_subset
# 3   2014     16  figshare_subset
# 4   2015    467  figshare_subset
# 5   2016    866  figshare_subset
# 6   2017    442  figshare_subset
# 7   2018   1089  figshare_subset
# 8   2019   1582  figshare_subset
# 9   2020   2470  figshare_subset
# 10  2021   3403  figshare_subset

# %%
#export to Figures folder
pub_dates_export_ready.to_csv('..\\..\\Figures\\Figure1\\repository_dates\\figshare_subset_pub_years.csv')

# %% [markdown]
# ## 6. What are the unweighted mean, median, and max file sizes among all ingested files?
# **Property:** File size
# **Related function:** `get_summary_statistics`

# %% [markdown]
# We first get the file size attribute using the crosswalk.

# %%
file_sizes = df.FigshareArticlesCrosswalk.file_size
file_sizes
# Out:
# 0        [6866146, 9545372, 6460828, 1569434, 9797854, ...
# 1        [837800, 289792, 42496, 56832, 67072, 71168, 7...
# 2          [239186, 227786, 170104, 225301, 152663, 77863]
# 3                                                 [158279]
# 4                                 [2296307, 497404, 56745]
#                                ...
# 10342                                              [77444]
# 10343                                             [185790]
# 10344                                             [137646]
# 10345                                             [109962]
# 10346                                             [153877]
# Name: files, Length: 10347, dtype: object

# %%
#replace None values with empty list
file_sizes = file_sizes.apply(lambda d: d if isinstance(d, list) else [])
file_sizes
# Out:
# 0        [6866146, 9545372, 6460828, 1569434, 9797854, ...
# 1        [837800, 289792, 42496, 56832, 67072, 71168, 7...
# 2          [239186, 227786, 170104, 225301, 152663, 77863]
# 3                                                 [158279]
# 4                                 [2296307, 497404, 56745]
#                                ...
# 10342                                              [77444]
# 10343                                             [185790]
# 10344                                             [137646]
# 10345                                             [109962]
# 10346                                             [153877]
# Name: files, Length: 10347, dtype: object

# %%
#collapse into single column - each file size in own row, since we are interested in summary stats across all files
file_sizes_long = file_sizes.explode()
file_sizes_long
# Out:
# 0        6866146
# 0        9545372
# 0        6460828
# 0        1569434
# 0        9797854
#           ...
# 10342      77444
# 10343     185790
# 10344     137646
# 10345     109962
# 10346     153877
# Name: files, Length: 31926, dtype: object

# %%
#drop NaN values, so median calculates correctly
file_sizes_long = file_sizes_long.dropna()
file_sizes_long
# Out:
# 0        6866146
# 0        9545372
# 0        6460828
# 0        1569434
# 0        9797854
#           ...
# 10342      77444
# 10343     185790
# 10344     137646
# 10345     109962
# 10346     153877
# Name: files, Length: 31894, dtype: object

# %%
#get summary statistics
analysis.get_summary_statistics(file_sizes_long)
# Out:
# {'mean': 147661899.27497336, 'median': 157358.0, 'max': 570679833692}

# %% [markdown]
# ## 7. What are the mean, median, and max number of files per object?
# **Property:** URL
# **Related function:** `get_summary_statistics`

# %% [markdown]
# `missing` is set to an empty list so that the `None` values for objects without files have "zero files"

# %%
files = df.FigshareArticlesCrosswalk.url
files
# Out:
# 0        [https://ndownloader.figshare.com/files/278296...
# 1        [https://ndownloader.figshare.com/files/287843...
# 2        [https://ndownloader.figshare.com/files/288459...
# 3          [https://ndownloader.figshare.com/files/289627]
# 4        [https://ndownloader.figshare.com/files/291521...
#                                ...
# 10342    [https://ndownloader.figshare.com/files/31645340]
# 10343    [https://ndownloader.figshare.com/files/31645343]
# 10344    [https://ndownloader.figshare.com/files/31645349]
# 10345    [https://ndownloader.figshare.com/files/31645355]
# 10346    [https://ndownloader.figshare.com/files/31646025]
# Name: files, Length: 10347, dtype: object

# %%
#replace None with empty list
files = files.apply(lambda d: d if isinstance(d, list) else [])
files
# Out:
# 0        [https://ndownloader.figshare.com/files/278296...
# 1        [https://ndownloader.figshare.com/files/287843...
# 2        [https://ndownloader.figshare.com/files/288459...
# 3          [https://ndownloader.figshare.com/files/289627]
# 4        [https://ndownloader.figshare.com/files/291521...
#                                ...
# 10342    [https://ndownloader.figshare.com/files/31645340]
# 10343    [https://ndownloader.figshare.com/files/31645343]
# 10344    [https://ndownloader.figshare.com/files/31645349]
# 10345    [https://ndownloader.figshare.com/files/31645355]
# 10346    [https://ndownloader.figshare.com/files/31646025]
# Name: files, Length: 10347, dtype: object

# %%
#get files per object
files_counts = files.apply(len)
files_counts
# Out:
# 0        12
# 1        14
# 2         6
# 3         1
# 4         3
#          ..
# 10342     1
# 10343     1
# 10344     1
# 10345     1
# 10346     1
# Name: files, Length: 10347, dtype: int64

# %%
#get summary statistics
analysis.get_summary_statistics(files_counts)
# Out:
# {'mean': 3.082439354402242, 'median': 1.0, 'max': 1100}

# %% [markdown]
# ## 8. What are the mean, median, and max total dataset size (summed across all files) per object?
# **Property:** Dataset size
# **Related function:** `get_summary_statistics`

# %%
dataset_sizes = df.FigshareArticlesCrosswalk.dataset_size
dataset_sizes
# Out:
# 0        [6866146, 9545372, 6460828, 1569434, 9797854, ...
# 1        [837800, 289792, 42496, 56832, 67072, 71168, 7...
# 2          [239186, 227786, 170104, 225301, 152663, 77863]
# 3                                                 [158279]
# 4                                 [2296307, 497404, 56745]
#                                ...
# 10342                                              [77444]
# 10343                                             [185790]
# 10344                                             [137646]
# 10345                                             [109962]
# 10346                                             [153877]
# Name: files, Length: 10347, dtype: object

# %%
#replace None values with empty list, file size of 0
dataset_sizes = dataset_sizes.apply(lambda d: d if isinstance(d, list) else [])
dataset_sizes
# Out:
# 0        [6866146, 9545372, 6460828, 1569434, 9797854, ...
# 1        [837800, 289792, 42496, 56832, 67072, 71168, 7...
# 2          [239186, 227786, 170104, 225301, 152663, 77863]
# 3                                                 [158279]
# 4                                 [2296307, 497404, 56745]
#                                ...
# 10342                                              [77444]
# 10343                                             [185790]
# 10344                                             [137646]
# 10345                                             [109962]
# 10346                                             [153877]
# Name: files, Length: 10347, dtype: object

# %%
#sum up size of files within object (sum up within each list in series)
dataset_sizes_total = dataset_sizes.apply(sum)
dataset_sizes_total
# Out:
# 0        51942464
# 1         4188905
# 2         1092903
# 3          158279
# 4         2850456
#            ...
# 10342       77444
# 10343      185790
# 10344      137646
# 10345      109962
# 10346      153877
# Name: files, Length: 10347, dtype: int64

# %%
#get summary statistics
analysis.get_summary_statistics(dataset_sizes_total, suppress_output=False);
# Out:
# mean: 455158849.47095776
# median: 72567.0
# max: 675675420197

# %% [markdown]
# ## 9. How many of each scientific domain are assigned?
# **Property:** Domain
# **Related function:** `domains.value_counts()`

# %%
domains = df.FigshareArticlesCrosswalk.domain
domains
# Out:
# 0                        [Genetics, Developmental Biology]
# 1        [Information and Computing Sciences, Biologica...
# 2        [Biotechnology, Biological Sciences, Informati...
# 3        [Information and Computing Sciences, Biologica...
# 4              [Biological Sciences, Cancer, Neuroscience]
#                                ...
# 10342                                      [Solid Tumours]
# 10343                                      [Solid Tumours]
# 10344                                      [Solid Tumours]
# 10345                                      [Solid Tumours]
# 10346    [Biochemistry, Molecular Biology, Pharmacology...
# Name: categories, Length: 10347, dtype: object

# %%
#expand so one domain per row
domains_all = domains.explode()
domains_all
# Out:
# 0                                            Genetics
# 0                               Developmental Biology
# 1                  Information and Computing Sciences
# 1                                 Biological Sciences
# 1                                        Biochemistry
#                              ...
# 10346                                    Pharmacology
# 10346      Chemical Sciences not elsewhere classified
# 10346    Biological Sciences not elsewhere classified
# 10346    Information Systems not elsewhere classified
# 10346                                        Virology
# Name: categories, Length: 66847, dtype: object

# %%
domains_counts = domains_all.value_counts().to_frame()
domains_counts['percent'] = domains_counts/len(domains) * 100
domains_counts.head(10)
# Out:
#                                                 categories    percent
# Biological Sciences not elsewhere classified          4292  41.480622
# Information Systems not elsewhere classified          3009  29.080893
# Genetics                                              2210  21.358848
# Biotechnology                                         1846  17.840920
# Cancer                                                1816  17.550981
# Medicine                                              1708  16.507200
# Chemical Sciences not elsewhere classified            1582  15.289456
# Science Policy                                        1524  14.728907
# Biochemistry                                          1488  14.380980
# Mathematical Sciences not elsewhere classified        1449  14.004059

# %% [markdown]
# ## 10. What is the mean number of characters (excluding whitespaces, if possible) per object?
# **Property:** Technical details
# **Related function:** `mean_characters`

# %%
# "usage notes" is not in crosswalk, none for this repo

# %% [markdown]
# ## 11-13. What are the mean and median total number of keyword terms per object, after merging results for Keyword, Geographic keyword, and Scientific keyword?
# **Property:** Keyword

# %%
print(df.FigshareArticlesCrosswalk.keyword)
# Out:
# 0        [genome-wide, screens, tinman, binding, sites,...
# 1        [feature-based, predicting, protease, substrat...
# 2        [exploiting, genomic, optimising, molecular, b...
# 3        [optimized, learning-based, meta-threading, mo...
# 4        [identifying, amino, signatures, hiv, predicti...
#                                ...
# 10342    [machine learning, gastric cancer, disease mod...
# 10343    [machine learning, gastric cancer, disease mod...
# 10344    [machine learning, gastric cancer, disease mod...
# 10345    [machine learning, gastric cancer, disease mod...
# 10346    [key therapeutic target, hypertensive peptide ...
# Name: tags, Length: 10347, dtype: object

# %%
print(df.FigshareArticlesCrosswalk.geographic_keyword)
# Out:
# 0        [genome-wide, screens, tinman, binding, sites,...
# 1        [feature-based, predicting, protease, substrat...
# 2        [exploiting, genomic, optimising, molecular, b...
# 3        [optimized, learning-based, meta-threading, mo...
# 4        [identifying, amino, signatures, hiv, predicti...
#                                ...
# 10342    [machine learning, gastric cancer, disease mod...
# 10343    [machine learning, gastric cancer, disease mod...
# 10344    [machine learning, gastric cancer, disease mod...
# 10345    [machine learning, gastric cancer, disease mod...
# 10346    [key therapeutic target, hypertensive peptide ...
# Name: tags, Length: 10347, dtype: object

# %%
print(df.FigshareArticlesCrosswalk.scientific_keyword)
# Out:
# 0        [genome-wide, screens, tinman, binding, sites,...
# 1        [feature-based, predicting, protease, substrat...
# 2        [exploiting, genomic, optimising, molecular, b...
# 3        [optimized, learning-based, meta-threading, mo...
# 4        [identifying, amino, signatures, hiv, predicti...
#                                ...
# 10342    [machine learning, gastric cancer, disease mod...
# 10343    [machine learning, gastric cancer, disease mod...
# 10344    [machine learning, gastric cancer, disease mod...
# 10345    [machine learning, gastric cancer, disease mod...
# 10346    [key therapeutic target, hypertensive peptide ...
# Name: tags, Length: 10347, dtype: object

# %%
#confirm all identical
keywords1 = df.FigshareArticlesCrosswalk.keyword
keywords2 = df.FigshareArticlesCrosswalk.geographic_keyword
keywords3 = df.FigshareArticlesCrosswalk.scientific_keyword

# %%
print(keywords1.equals(keywords2))
print(keywords2.equals(keywords3))
# Out:
# True
# True

# %%
#use keyword column since all keyword columns are identical
keywords = df.FigshareArticlesCrosswalk.keyword
keywords
# Out:
# 0        [genome-wide, screens, tinman, binding, sites,...
# 1        [feature-based, predicting, protease, substrat...
# 2        [exploiting, genomic, optimising, molecular, b...
# 3        [optimized, learning-based, meta-threading, mo...
# 4        [identifying, amino, signatures, hiv, predicti...
#                                ...
# 10342    [machine learning, gastric cancer, disease mod...
# 10343    [machine learning, gastric cancer, disease mod...
# 10344    [machine learning, gastric cancer, disease mod...
# 10345    [machine learning, gastric cancer, disease mod...
# 10346    [key therapeutic target, hypertensive peptide ...
# Name: tags, Length: 10347, dtype: object

# %%
keywords_counts = keywords1.apply(len)
keywords_counts
# Out:
# 0         8
# 1         6
# 2         8
# 3         6
# 4         6
#          ..
# 10342     9
# 10343     9
# 10344     9
# 10345     9
# 10346    32
# Name: tags, Length: 10347, dtype: int64

# %%
#get summary statistics
analysis.get_summary_statistics(keywords_counts, suppress_output = False);
# Out:
# mean: 9.812602686769111
# median: 7.0
# max: 61

# %% [markdown]
# ## 14. Who are the most common funding agencies for each repo? What are the object counts per agency?
# **Property:** Funding Agency

# %%
funders = df.FigshareArticlesCrosswalk.funding_agency
funders
# Out:
# 0        []
# 1        []
# 2        []
# 3        []
# 4        []
#          ..
# 10342    []
# 10343    []
# 10344    []
# 10345    []
# 10346    []
# Name: funding_list, Length: 10347, dtype: object

# %%
#may be more than one funder per object, so expand
funders_long = funders.explode()
funders_long
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 10342    NaN
# 10343    NaN
# 10344    NaN
# 10345    NaN
# 10346    NaN
# Name: funding_list, Length: 10563, dtype: object

# %%
funders_counts = funders_long.value_counts().to_frame()
funders_counts['percent'] = funders_counts['funding_list']/len(funders) * 100
funders_counts
# Out:
#                                                     funding_list   percent
# National Science Foundation                                   28  0.270610
# CSU Animal Cancer Shipley Chair in Comparative ...            25  0.241616
# National Natural Science Foundation of China                  19  0.183628
# Foundation for the National Institutes of Healt...            18  0.173963
# National Institutes of Health                                 15  0.144970
# ...                                                          ...       ...
# Google daydream                                                1  0.009665
# ERA-NET NEURON NeuroNiche project 01EW1708                     1  0.009665
# ERC advanced grant (Zf-BrainReg)                               1  0.009665
# Alexander-von-Humboldt Stiftung                                1  0.009665
# Open Fund of State Key Laboratory of Remote Sen...             1  0.009665
#
# [804 rows x 2 columns]

# %% [markdown]
# ## 15. What are the mean, median, and max number of Views per object?
# **Property:** Views
# **Related function:** `get_summary_statistics`

# %%
views = df.FigshareArticlesCrosswalk.views
views

# %%
#confirm none - variable not available for this repo
print(df.FigshareArticlesCrosswalk.views)
# Out:
# None

# %% [markdown]
# ## 16. What are the mean, median, and max (total) number of downloads per object?
# **Property:** Downloads
# **Related function:** `get_summary_statistics`

# %%
downloads = df.FigshareArticlesCrosswalk.downloads
downloads

# %%
#confirm none - variable not available for this repo
print(df.FigshareArticlesCrosswalk.downloads)
# Out:
# None

# %% [markdown]
# ## 17. What are the mean, median, and max Citation counts per object?
# **Property:** Citation count
# **Related function:** `get_summary_statistics`

# %%
citation_count = df.FigshareArticlesCrosswalk.citation_count
citation_count

# %%
#confirm none - variable not available for this repo
print(df.FigshareArticlesCrosswalk.citation_count)
# Out:
# None

# %% [markdown]
# ## 18. How many objects contain each given resource type?
# **Property:** Resource type

# %%
resource_types = df.FigshareArticlesCrosswalk.resource_type
resource_types
# Out:
# 0        dataset
# 1        dataset
# 2        dataset
# 3        dataset
# 4        dataset
#           ...
# 10342    dataset
# 10343    dataset
# 10344    dataset
# 10345    dataset
# 10346    dataset
# Name: defined_type_name_metadata, Length: 10347, dtype: object

# %%
resource_counts = resource_types.value_counts().to_frame()
resource_counts['percent'] = round(resource_counts['defined_type_name_metadata']/len(resource_types) * 100)
resource_counts
# Out:
#           defined_type_name_metadata  percent
# dataset                        10132     98.0
# software                         213      2.0
# model                              2      0.0

# %% [markdown]
# ## 19. How many objects contain each type of file extension given?
# **Property:** File Extension
# **Related function:** `get_file_extensions`

# %%
files = df.FigshareArticlesCrosswalk.file_extension
files
# Out:
# 0        [Figure_S1.tif, Figure_S2.tif, Figure_S3.tif, ...
# 1        [Figure_S1.tif, Table_S8.doc, Table_S7.doc, Ta...
# 2        [File_S1.xlsx, File_S2.xlsx, File_S3.xlsx, Fil...
# 3                                            [Text_S1.pdf]
# 4            [Figure_S1.pdf, Figure_S2.pdf, Table_S1.xlsx]
#                                ...
# 10342                          [Supplementary Table 2.pdf]
# 10343                          [Supplementary Table 3.pdf]
# 10344                          [Supplementary Table 4.pdf]
# 10345                          [Supplementary Table 5.pdf]
# 10346                              [jf1c04555_si_001.xlsx]
# Name: files, Length: 10347, dtype: object

# %%
#add ID column to make easier to count by object
files_ids = pd.concat([ids, files], axis = 1)
files_ids
# Out:
#              id                                              files
# 0        114867  [Figure_S1.tif, Figure_S2.tif, Figure_S3.tif, ...
# 1        116703  [Figure_S1.tif, Table_S8.doc, Table_S7.doc, Ta...
# 2        116813  [File_S1.xlsx, File_S2.xlsx, File_S3.xlsx, Fil...
# 3        117032                                      [Text_S1.pdf]
# 4        117391      [Figure_S1.pdf, Figure_S2.pdf, Table_S1.xlsx]
# ...         ...                                                ...
# 10342  17113517                        [Supplementary Table 2.pdf]
# 10343  17113523                        [Supplementary Table 3.pdf]
# 10344  17113529                        [Supplementary Table 4.pdf]
# 10345  17113550                        [Supplementary Table 5.pdf]
# 10346  17114094                            [jf1c04555_si_001.xlsx]
#
# [10347 rows x 2 columns]

# %%
#replace the None values with empty lists so the count of string values evaluates to 0
files_ids = files_ids.apply(
    lambda row: row.apply(
        lambda cell: cell if cell else []
    ),
    axis=1
)
files_ids
# Out:
#              id                                              files
# 0        114867  [Figure_S1.tif, Figure_S2.tif, Figure_S3.tif, ...
# 1        116703  [Figure_S1.tif, Table_S8.doc, Table_S7.doc, Ta...
# 2        116813  [File_S1.xlsx, File_S2.xlsx, File_S3.xlsx, Fil...
# 3        117032                                      [Text_S1.pdf]
# 4        117391      [Figure_S1.pdf, Figure_S2.pdf, Table_S1.xlsx]
# ...         ...                                                ...
# 10342  17113517                        [Supplementary Table 2.pdf]
# 10343  17113523                        [Supplementary Table 3.pdf]
# 10344  17113529                        [Supplementary Table 4.pdf]
# 10345  17113550                        [Supplementary Table 5.pdf]
# 10346  17114094                            [jf1c04555_si_001.xlsx]
#
# [10347 rows x 2 columns]

# %% [markdown]
# The following code separates the full file extensions (all dot-separated values after the first dot) for a list of files and creates a set, allowing us to only look at the number of objects that contain a given extension. It keeps only unique file extensions: for instance, if an object has 5 .tif files, there is only 1 .tif items in the object list of file extensions.

# %%
files_extension_set = files_ids['files'].apply(
    lambda file_list: list({''.join(Path(file).suffixes) for file in file_list})
)
files_extension_set
# Out:
# 0        [.tif, .pdf, .xls]
# 1              [.doc, .tif]
# 2             [.xlsx, .zip]
# 3                    [.pdf]
# 4             [.xlsx, .pdf]
#                 ...
# 10342                [.pdf]
# 10343                [.pdf]
# 10344                [.pdf]
# 10345                [.pdf]
# 10346               [.xlsx]
# Name: files, Length: 10347, dtype: object

# %%
#expand so each file within object is own row
files_ext_ids = files_extension_set.explode().to_frame()
files_ext_ids
# Out:
#        files
# 0       .tif
# 0       .pdf
# 0       .xls
# 1       .doc
# 1       .tif
# ...      ...
# 10342   .pdf
# 10343   .pdf
# 10344   .pdf
# 10345   .pdf
# 10346  .xlsx
#
# [14308 rows x 1 columns]

# %%
#group by extension type to count how many objects have each file type
ext_grouped = files_ext_ids.groupby('files').value_counts().to_frame().sort_values(0, ascending = False)
ext_grouped['percent'] = round(ext_grouped[0]/len(files_ids) * 100)

# %%
#this is an ESTIMATE, pre-cleaning
ext_grouped[ext_grouped['percent'] >= 5]
# Out:
#           0  percent
# files
# .xls   2780     27.0
# .xlsx  1504     15.0
# .zip   1077     10.0
# .docx   837      8.0
# .pdf    703      7.0
# .csv    533      5.0

# %%
ext_grouped.head(20)
# Out:
#             0  percent
# files
# .xls     2780     27.0
# .xlsx    1504     15.0
# .zip     1077     10.0
# .docx     837      8.0
# .pdf      703      7.0
# .csv      533      5.0
# .XLSX     436      4.0
# .DOCX     347      3.0
# .PDF      343      3.0
# .txt      320      3.0
# .tif      217      2.0
# .ZIP      134      1.0
# .doc      101      1.0
# .CSV       99      1.0
# .jpg       92      1.0
# .tar.gz    84      1.0
# .rar       68      1.0
# .json      51      0.0
# .mat       51      0.0
#            51      0.0

# %%
#confirm accuracy - there should be 51 objects with .json files
len(files_ext_ids[files_ext_ids['files'] == '.json'] )
# Out:
# 51

# %%
#export for further clean up, refining estimates, and plotting

# %%
ext_grouped_ready = files_ext_ids.reset_index(level=0)
ext_grouped_ready
# Out:
#        index  files
# 0          0   .tif
# 1          0   .pdf
# 2          0   .xls
# 3          1   .doc
# 4          1   .tif
# ...      ...    ...
# 14303  10342   .pdf
# 14304  10343   .pdf
# 14305  10344   .pdf
# 14306  10345   .pdf
# 14307  10346  .xlsx
#
# [14308 rows x 2 columns]

# %%
#reset index and update column names
ext_grouped_ready.columns = ['index', 'files']

#add column with name of repo
ext_grouped_ready['repo'] = 'figshare_subset'

ext_grouped_ready
# Out:
#        index  files             repo
# 0          0   .tif  figshare_subset
# 1          0   .pdf  figshare_subset
# 2          0   .xls  figshare_subset
# 3          1   .doc  figshare_subset
# 4          1   .tif  figshare_subset
# ...      ...    ...              ...
# 14303  10342   .pdf  figshare_subset
# 14304  10343   .pdf  figshare_subset
# 14305  10344   .pdf  figshare_subset
# 14306  10345   .pdf  figshare_subset
# 14307  10346  .xlsx  figshare_subset
#
# [14308 rows x 3 columns]

# %%
ext_grouped_ready['index'].unique() #confirmed accurate
# Out:
# array([    0,     1,     2, ..., 10344, 10345, 10346], dtype=int64)

# %%
#export to Figures folder
ext_grouped_ready.to_csv('..\\..\\Figures\\Figure2\\file_ext_data\\figshare_subset_extensions.csv')

# %% [markdown]
# ## 19.5 How many files of each type of file extension are present?
# **Property:** File extension

# %%
#pick up from files
files
# Out:
# 0        [Figure_S1.tif, Figure_S2.tif, Figure_S3.tif, ...
# 1        [Figure_S1.tif, Table_S8.doc, Table_S7.doc, Ta...
# 2        [File_S1.xlsx, File_S2.xlsx, File_S3.xlsx, Fil...
# 3                                            [Text_S1.pdf]
# 4            [Figure_S1.pdf, Figure_S2.pdf, Table_S1.xlsx]
#                                ...
# 10342                          [Supplementary Table 2.pdf]
# 10343                          [Supplementary Table 3.pdf]
# 10344                          [Supplementary Table 4.pdf]
# 10345                          [Supplementary Table 5.pdf]
# 10346                              [jf1c04555_si_001.xlsx]
# Name: files, Length: 10347, dtype: object

# %%
#remove None
files_ext_all = pd.Series(filter(None, files))
files_ext_all
# Out:
# 0        [Figure_S1.tif, Figure_S2.tif, Figure_S3.tif, ...
# 1        [Figure_S1.tif, Table_S8.doc, Table_S7.doc, Ta...
# 2        [File_S1.xlsx, File_S2.xlsx, File_S3.xlsx, Fil...
# 3                                            [Text_S1.pdf]
# 4            [Figure_S1.pdf, Figure_S2.pdf, Table_S1.xlsx]
#                                ...
# 10310                          [Supplementary Table 2.pdf]
# 10311                          [Supplementary Table 3.pdf]
# 10312                          [Supplementary Table 4.pdf]
# 10313                          [Supplementary Table 5.pdf]
# 10314                              [jf1c04555_si_001.xlsx]
# Length: 10315, dtype: object

# %%
#expand so each item in own row
files_ext_all = files_ext_all.explode()
files_ext_all
# Out:
# 0                    Figure_S1.tif
# 0                    Figure_S2.tif
# 0                    Figure_S3.tif
# 0                    Figure_S4.tif
# 0                    Figure_S5.tif
#                    ...
# 10310    Supplementary Table 2.pdf
# 10311    Supplementary Table 3.pdf
# 10312    Supplementary Table 4.pdf
# 10313    Supplementary Table 5.pdf
# 10314        jf1c04555_si_001.xlsx
# Length: 31894, dtype: object

# %%
files_ext_all_df = files_ext_all.apply(lambda fn: Path(fn).suffixes).value_counts().to_frame()
files_ext_all_df.head(10)
# Out:
#             0
# [.xls]   3046
# [.tif]   2482
# [.csv]   2363
# [.mp4]   2107
# [.xlsx]  1783
# [.zip]   1604
# [.jpg]   1566
# [.docx]  1378
# [.pdf]   1234
# [.txt]   1209

# %% [markdown]
# ## 20. How many objects contain each type of File format given?
# **Property:** File format

# %%
file_formats = df.FigshareArticlesCrosswalk.file_format
file_formats

# %%
#confirm missing for this repo
print(df.FigshareArticlesCrosswalk.file_format)
# Out:
# None

# %% [markdown]
# ## 21. How many objects contain each type of Media type given?
# **Property:** Media type

# %%
media_types = df.FigshareArticlesCrosswalk.media_type
media_types

# %%
#confirm missing for this repo
print(df.FigshareArticlesCrosswalk.media_type)
# Out:
# None

# %% [markdown]
# ## 22. a) How many objects report one related resource type, and b) how many objects report each of those types? c) How many objects report multiple related resource types (regardless of which types)?
# **Property:** Related resource type

# %%
related_resource_types = df.FigshareArticlesCrosswalk.related_resource_type
related_resource_types

# %%
#confirm missing for this repo
print(df.FigshareArticlesCrosswalk.related_resource_type)
# Out:
# None

# %% [markdown]
# ## 23-25. If there is an entry for an object in one of the three properties (Original data URL, Primary manuscript PID/URL, and Related resource identifier) count as Related resources = True and then count the number of objects that return True.
# **Property:** Related Resource Identifier

# %%
related_resource1 = df.FigshareArticlesCrosswalk.original_data_url
related_resource2 = df.FigshareArticlesCrosswalk.primary_manuscript
related_resource3 = df.FigshareArticlesCrosswalk.related_resource_identifier

# %%
print(related_resource1)
# Out:
# None

# %%
print(related_resource2)
# Out:
# 0        10.1371/journal.pgen.1003195
# 1        10.1371/journal.pone.0050300
# 2        10.1371/journal.pone.0048862
# 3        10.1371/journal.pone.0050200
# 4        10.1371/journal.pone.0049538
#                      ...
# 10342           10.2217/fon-2021-1059
# 10343           10.2217/fon-2021-1059
# 10344           10.2217/fon-2021-1059
# 10345           10.2217/fon-2021-1059
# 10346        10.1021/acs.jafc.1c04555
# Name: resource_doi_metadata, Length: 10347, dtype: object

# %%
print(related_resource3)
# Out:
# 0        10.1371/journal.pgen.1003195
# 1        10.1371/journal.pone.0050300
# 2        10.1371/journal.pone.0048862
# 3        10.1371/journal.pone.0050200
# 4        10.1371/journal.pone.0049538
#                      ...
# 10342           10.2217/fon-2021-1059
# 10343           10.2217/fon-2021-1059
# 10344           10.2217/fon-2021-1059
# 10345           10.2217/fon-2021-1059
# 10346        10.1021/acs.jafc.1c04555
# Name: resource_doi_metadata, Length: 10347, dtype: object

# %%
#confirm related_resource2 and related_resource3 are identical
related_resource2.equals(related_resource3)
# Out:
# True

# %%
#concatenate resources along with id
related_resource_all = pd.concat([related_resource1, related_resource2], axis = 1)
related_resource_all = pd.concat([related_resource_all, ids], axis = 1)
related_resource_all
# Out:
#               resource_doi_metadata        id
# 0      10.1371/journal.pgen.1003195    114867
# 1      10.1371/journal.pone.0050300    116703
# 2      10.1371/journal.pone.0048862    116813
# 3      10.1371/journal.pone.0050200    117032
# 4      10.1371/journal.pone.0049538    117391
# ...                             ...       ...
# 10342         10.2217/fon-2021-1059  17113517
# 10343         10.2217/fon-2021-1059  17113523
# 10344         10.2217/fon-2021-1059  17113529
# 10345         10.2217/fon-2021-1059  17113550
# 10346      10.1021/acs.jafc.1c04555  17114094
#
# [10347 rows x 2 columns]

# %%
#check how many have not None values
rr_count = related_resource_all['resource_doi_metadata'].count()
rr_count
# Out:
# 8960

# %%
#confirm, make new df
rr_objects = related_resource_all.dropna()
rr_objects
# Out:
#               resource_doi_metadata        id
# 0      10.1371/journal.pgen.1003195    114867
# 1      10.1371/journal.pone.0050300    116703
# 2      10.1371/journal.pone.0048862    116813
# 3      10.1371/journal.pone.0050200    117032
# 4      10.1371/journal.pone.0049538    117391
# ...                             ...       ...
# 10342         10.2217/fon-2021-1059  17113517
# 10343         10.2217/fon-2021-1059  17113523
# 10344         10.2217/fon-2021-1059  17113529
# 10345         10.2217/fon-2021-1059  17113550
# 10346      10.1021/acs.jafc.1c04555  17114094
#
# [8960 rows x 2 columns]

# %%
#NOTE: also need to clean up empty cells in here (blank, not None)
rr_objects_ready = rr_objects.replace('', None)
rr_objects_ready
# Out:
#               resource_doi_metadata        id
# 0      10.1371/journal.pgen.1003195    114867
# 1      10.1371/journal.pone.0050300    116703
# 2      10.1371/journal.pone.0048862    116813
# 3      10.1371/journal.pone.0050200    117032
# 4      10.1371/journal.pone.0049538    117391
# ...                             ...       ...
# 10342         10.2217/fon-2021-1059  17113517
# 10343         10.2217/fon-2021-1059  17113523
# 10344         10.2217/fon-2021-1059  17113529
# 10345         10.2217/fon-2021-1059  17113550
# 10346      10.1021/acs.jafc.1c04555  17114094
#
# [8960 rows x 2 columns]

# %%
rr_objects_ready = rr_objects_ready.dropna()
rr_objects_ready
# Out:
#               resource_doi_metadata        id
# 0      10.1371/journal.pgen.1003195    114867
# 1      10.1371/journal.pone.0050300    116703
# 2      10.1371/journal.pone.0048862    116813
# 3      10.1371/journal.pone.0050200    117032
# 4      10.1371/journal.pone.0049538    117391
# ...                             ...       ...
# 10342         10.2217/fon-2021-1059  17113517
# 10343         10.2217/fon-2021-1059  17113523
# 10344         10.2217/fon-2021-1059  17113529
# 10345         10.2217/fon-2021-1059  17113550
# 10346      10.1021/acs.jafc.1c04555  17114094
#
# [8906 rows x 2 columns]

# %%
print(f'There are {len(rr_objects_ready)} objects with a related resource link')
# Out:
# There are 8906 objects with a related resource link

# %% [markdown]
# ## 23-25. Also, what is the mean number of related resource links per object (again looking at the three properties (Original data URL, Primary manuscript PID/URL, and Related resource identifier)?
# **Property:** Related Resource Identifier

# %% [markdown]
# In this case, all objects have at least one related resource, so no need to subset to only objects with related resources, in order to calculate mean/median number of related resources.

# %%
#function to count links
def count_links(entry):
    try:
        return len(entry)
    except TypeError:
        return 0

# %% [markdown]
# Function `count_links` is expecting a list (in event of multiple links)

# %%
#replace the column string values with lists
related_resource_list = rr_objects_ready.apply(
    lambda row: row.apply(
        lambda cell: [cell] if cell else []
    ),
    axis=1
)
related_resource_list
# Out:
#                 resource_doi_metadata          id
# 0      [10.1371/journal.pgen.1003195]    [114867]
# 1      [10.1371/journal.pone.0050300]    [116703]
# 2      [10.1371/journal.pone.0048862]    [116813]
# 3      [10.1371/journal.pone.0050200]    [117032]
# 4      [10.1371/journal.pone.0049538]    [117391]
# ...                               ...         ...
# 10342         [10.2217/fon-2021-1059]  [17113517]
# 10343         [10.2217/fon-2021-1059]  [17113523]
# 10344         [10.2217/fon-2021-1059]  [17113529]
# 10345         [10.2217/fon-2021-1059]  [17113550]
# 10346      [10.1021/acs.jafc.1c04555]  [17114094]
#
# [8906 rows x 2 columns]

# %%
#remove id column before counting
related_resource_list = related_resource_list.drop('id', axis=1)
related_resource_list
# Out:
#                 resource_doi_metadata
# 0      [10.1371/journal.pgen.1003195]
# 1      [10.1371/journal.pone.0050300]
# 2      [10.1371/journal.pone.0048862]
# 3      [10.1371/journal.pone.0050200]
# 4      [10.1371/journal.pone.0049538]
# ...                               ...
# 10342         [10.2217/fon-2021-1059]
# 10343         [10.2217/fon-2021-1059]
# 10344         [10.2217/fon-2021-1059]
# 10345         [10.2217/fon-2021-1059]
# 10346      [10.1021/acs.jafc.1c04555]
#
# [8906 rows x 1 columns]

# %%
links_per_object = related_resource_list.apply(
    lambda row: sum([count_links(entry) for entry in row]),
    axis=1
)

links_per_object
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 10342    1
# 10343    1
# 10344    1
# 10345    1
# 10346    1
# Length: 8906, dtype: int64

# %%
print(f'mean {round(links_per_object.mean(), 3)} links per object')
# Out:
# mean 1.0 links per object

# %%
print(f'median {round(links_per_object.median(), 3)} links per object')
# Out:
# median 1.0 links per object

# %%
8906/10347 * 100
# Out:
# 86.073257949164

# %% [markdown]
# ## 26. How many objects report each relation type? How many objects report multiple relation types, regardless of what those types are?
# **Property:** Related resource relation type

# %%
relation_type = df.FigshareArticlesCrosswalk.related_resource_relation_type
relation_type

# %%
#confirm missing for this repo
print(df.FigshareArticlesCrosswalk.related_resource_relation_type)
# Out:
# None

# %% [markdown]
# ## 27. For repositories that store the full citation in a designated field, how many objects have a populated citation? How many objects have a citation and a URL or other actionable link?
# **Property:** Citation

# %%
citations = df.FigshareArticlesCrosswalk.citation
citations
# Out:
# 0        Jin, Hong; Stojnic, Robert; Adryan, Boris; Ozd...
# 1        Song, Jiangning; Tan, Hao; J. Perry, Andrew; A...
# 2        O'Hagan, Steve; Knowles, Joshua; Kell, Douglas...
# 3        Brylinski, Michal; Lingam, Daswanth (2015): Te...
# 4        G. Holman, Alexander; Gabuzda, Dana (2016): A ...
#                                ...
# 10342    Xu, Jianmin; Xu, Binghua; Li, Yipeng; Su, Zhij...
# 10343    Xu, Jianmin; Xu, Binghua; Li, Yipeng; Su, Zhij...
# 10344    Xu, Jianmin; Xu, Binghua; Li, Yipeng; Su, Zhij...
# 10345    Xu, Jianmin; Xu, Binghua; Li, Yipeng; Su, Zhij...
# 10346    Kalyan, Gazal; Junghare, Vivek; Khan, Mohammad...
# Name: citation, Length: 10347, dtype: object

# %%
#check number missing citations
citations.isna().sum()
# Out:
# 0

# %%
print(f'There are {len(citations)} objects with a citation')
# Out:
# There are 10347 objects with a citation
